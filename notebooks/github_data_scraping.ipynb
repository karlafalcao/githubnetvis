# %%
# This script requires github3.py version 0.9.6
# pip install github3.py

import os
import pandas as pd
from github3 import login

GITHUB_API_TOKEN = os.environ.get('GITHUB_API_TOKEN')
gh = login(token=GITHUB_API_TOKEN)
LOCATION = 'Recife'

gh.user('karlafalcao');

# %%
def queries_list(location=LOCATION):
    return (
        'location:{} followers:>1'.format(location),
        'location:{} followers:1'.format(location),
        'location:{} followers:0'.format(location),
    )


# obs.: gh.search_users() nao retorna todos os atributos do objeto
def search_users(query):
    return [u.user for u in gh.search_users(query, sort='followers')]


def fetch_gh_users():
    return [search_users(q) for q in queries_list()]

# %%
## procura pela lista de interesse
## porem, gh.search_users() nao retorna todos os atributos do objeto
ghusers_batches = fetch_gh_users()   

##################################################################
## teste

# print('object: ', ghusers_batches[0][0])
# print('name: ', ghusers_batches[0][0].name)
# print('id: ', ghusers_batches[0][0].id)
# print('numero de seguidores: ', ghusers_batches[0][0].followers)
# print('criado em: ', ghusers_batches[0][0].created_at)

# >>> object:  tarruda
# >>> name:  
# >>> id:  842846
# >>> numero de seguidores:  0
# >>> criado em:  None

print(ghusers_batches)
# Out:
# [[<User [tarruda:]>, <User [mairatma:]>, <User [joselitojunior1:]>, <User [marcelcaraciolo:]>, <User [luanfonceca:]>, <User [deividazevedo2:]>, <User [simoneas02:]>, <User [gileno:]>, <User [filipeximenes:]>, <User [renatooliveira:]>, <User [luiztiago:]>, <User [ac-pm:]>, <User [fernandocastor:]>, <User [henvic:]>, <User [clovisdasilvaneto:]>, <User [fjsj:]>, <User [zimmerle:]>, <User [adrielcafe:]>, <User [talitaoliveira:]>, <User [arthuralvim:]>, <User [paulorec:]>, <User [dmesquita:]>, <User [ktquez:]>, <User [guilhermefarias:]>, <User [brunofarache:]>, <User [lailsonbm:]>, <User [lmmenge:]>, <User [brunobasto:]>, <User [guiocavalcanti:]>, <User [pcstl:]>, <User [roselmamendes:]>, <User [horaciojcfilho:]>, <User [dakerfp:]>, <User [caiorss:]>, <User [interaminense:]>, <User [victorlaerte:]>, <User [diegocarloslima:]>, <User [miguelarauj1o:]>, <User [diegonvs:]>, <User [eduardocruz:]>, <User [henriquemenezes:]>, <User [chocoelho:]>, <User [karlafalcao:]>, <User [thiagodiniz:]>, <User [pauloborba:]>, <User [jonathanslima:]>, <User [gallindo:]>, <User [andrewesteves:]>, <User [vinicius3w:]>, <User [vanessa:]>, <User [jordanamorais:]>, <User [Suburbanno:]>, <User [gvc:]>, <User [dvro:]>, <User [douglaslira:]>, <User [kessiacastro:]>, <User [ovictoraurelio:]>, <User [andresmachado:]>, <User [embs:]>, <User [tomersimis:]>, <User [marcellustavares:]>, <User [victorcarrico:]>, <User [tarcisio-marinho:]>, <User [filipevarjao:]>, <User [iagobelo:]>, <User [thiagoarrais:]>, <User [deyvisonrocha:]>, <User [patrickrbc:]>, <User [alexpessoajr:]>, <User [brunolimawd:]>, <User [arthurmichel:]>, <User [brunnogomes:]>, <User [irgmedeiros:]>, <User [Cisneiros:]>, <User [mauriciomanoel:]>, <User [mayrarabelo:]>, <User [akshaykarle:]>, <User [lhaisrs:]>, <User [ramonsantos:]>, <User [HaysaRodrigues:]>, <User [victorfsf:]>, <User [tuliohmendes:]>, <User [leopoldomt:]>, <User [yelken:]>, <User [LeonardoGaldino:]>, <User [Juniorlimaivd:]>, <User [JoaoGFarias:]>, <User [paulolieuthier:]>, <User [pereiragislene:]>, <User [dayvsonlima:]>, <User [fchicout:]>, <User [lmarinho:]>, <User [jayralencar:]>, <User [frankjuniorr:]>, <User [felipefarias:]>, <User [mateusrevoredo:]>, <User [arthurms:]>, <User [itsmealves:]>, <User [meiralins:]>, <User [t0rr3sp3dr0:]>, <User [RodrigoCastiel:]>, <User [hamorim:]>, <User [FranckAJ:]>, <User [julianalucena:]>, <User [casevictor:]>, <User [lipse:]>, <User [ThaisaMirely:]>, <User [marcosisocram:]>, <User [espellcaste:]>, <User [Gustavomagalhaes:]>, <User [leticiamachado:]>, <User [abelb0rges:]>, <User [rpragana:]>, <User [WandersonAlves:]>, <User [omailson:]>, <User [rvlb-19:]>, <User [mirjahal:]>, <User [alexjosesilva:]>, <User [peaonunes:]>, <User [matheusmariano:]>, <User [inacionery:]>, <User [daniellqueiroz:]>, <User [andersonresende:]>, <User [caiobsouza:]>, <User [araujoraphael:]>, <User [djalmaafilho:]>, <User [eron93br:]>, <User [TigerRobocop:]>, <User [AbrantesMar:]>, <User [thiago-farias:]>, <User [eduardo-melo:]>, <User [gabrieldluca:]>, <User [herbertt:]>, <User [FranciscoMarinho:]>, <User [hugobessa:]>, <User [cleydyr:]>, <User [felipedealbuquerque:]>, <User [PedroRossi:]>, <User [lauromoura:]>, <User [rodolfoestevam:]>, <User [igormp:]>, <User [matheusFTC:]>, <User [alvarocavalcanti:]>, <User [rafaprax:]>, <User [leuthier:]>, <User [foolOnTheHill:]>, <User [setanta:]>, <User [jeftarmascarenhas:]>, <User [joseronierison:]>, <User [eudesll:]>, <User [nielsonsantana:]>, <User [guilhermepaiva:]>, <User [brandizzi:]>, <User [rcaval:]>, <User [pedroqueiroz:]>, <User [gcaraciolo:]>, <User [hpbl:]>, <User [oliveriojnn:]>, <User [alinedoleron:]>, <User [raquelguimaraes:]>, <User [rcbop:]>, <User [rsarai:]>, <User [andreldm:]>, <User [acmh:]>, <User [brunovpl:]>, <User [rsilvabr:]>, <User [lpmfilho:]>, <User [anantpaatra:]>, <User [cassiolpaixao90:]>, <User [atriciasabino:]>, <User [ThiagoAugustoSM:]>, <User [alocjr:]>, <User [amandasavluchinske:]>, <User [sgosantos:]>, <User [caionovaes:]>, <User [mabj:]>, <Use ...

# %%
##################################################################

## chama gh.user() - tratamento individual
## porque assim retorna todos os atributos do objeto
full_ghusers_batches = [[]]

for u in ghusers_batches:
    for v in u:
        full_ghusers_batches[0].append(gh.user(v))

##################################################################
## teste

# print('\nobject: ', full_ghusers_batches[0][0])
# print('name: ', full_ghusers_batches[0][0].name)
# print('id: ', full_ghusers_batches[0][0].id)
# print('numero de seguidores: ', full_ghusers_batches[0][0].followers)
# print('criado em: ', full_ghusers_batches[0][0].created_at)

# >>> object:  tarruda
# >>> name:  Thiago de Arruda
# >>> id:  842846
# >>> numero de seguidores:  568
# >>> criado em:  2011-06-10 19:33:28+00:00
##################################################################

full_ghusers_batches
# Out:
# [[<User [tarruda:Thiago de Arruda]>,
#   <User [mairatma:Maira Bello]>,
#   <User [joselitojunior1:Joselito]>,
#   <User [marcelcaraciolo:Marcel]>,
#   <User [luanfonceca:Luan Fonseca]>,
#   <User [deividazevedo2:Deivid Azevedo]>,
#   <User [simoneas02:Simone Amorim]>,
#   <User [gileno:Gileno Filho]>,
#   <User [filipeximenes:Filipe A Ximenes]>,
#   <User [renatooliveira:Renato Oliveira]>,
#   <User [luiztiago:Luiz Tiago Oliveira]>,
#   <User [ac-pm:acpm]>,
#   <User [fernandocastor:Fernando Castor]>,
#   <User [henvic:Henrique Vicente]>,
#   <User [clovisdasilvaneto:Clóvis Neto]>,
#   <User [fjsj:Flávio Juvenal da Silva Junior]>,
#   <User [zimmerle:Felipe Zimmerle]>,
#   <User [adrielcafe:Adriel Café]>,
#   <User [talitaoliveira:Talita Oliveira]>,
#   <User [arthuralvim:Arthur Alvim]>,
#   <User [paulorec:Paulo Amorim]>,
#   <User [dmesquita:Déborah Mesquita]>,
#   <User [ktquez:Alan Ktquez]>,
#   <User [guilhermefarias:Guilherme Farias]>,
#   <User [brunofarache:Bruno Farache]>,
#   <User [lailsonbm:Lailson Bandeira]>,
#   <User [lmmenge:Lucas Menge]>,
#   <User [brunobasto:Bruno Basto]>,
#   <User [guiocavalcanti:Guilherme Cavalcanti]>,
#   <User [pcstl:Pedro Castilho]>,
#   <User [roselmamendes:Roselma Mendes]>,
#   <User [horaciojcfilho:Horácio Filho]>,
#   <User [dakerfp:Daker Fernandes Pinheiro]>,
#   <User [caiorss:Caio Rordrigues]>,
#   <User [interaminense:Adriano]>,
#   <User [victorlaerte:Victor Laerte Oliveira]>,
#   <User [diegocarloslima:Diego Lima]>,
#   <User [miguelarauj1o:Miguel Araújo]>,
#   <User [diegonvs:Diego Nascimento]>,
#   <User [eduardocruz:Eduardo Cruz ]>,
#   <User [henriquemenezes:Henrique Menezes]>,
#   <User [chocoelho:Carlos Coêlho]>,
#   <User [karlafalcao:Karla Falcão]>,
#   <User [thiagodiniz:Thiago Diniz]>,
#   <User [pauloborba:Paulo Borba]>,
#   <User [jonathanslima:Jonathan]>,
#   <User [gallindo:Miguel Angelo]>,
#   <User [andrewesteves:Andrew Esteves]>,
#   <User [vinicius3w:Vinicius Cardoso Garcia]>,
#   <User [vanessa:Vanessa Barreiros]>,
#   <User [jordanamorais:Jordana Morais]>,
#   <User [Suburbanno:Vinicius R]>,
#   <User [gvc:Guilherme Carvalho]>,
#   <User [dvro:Dayvid Victor]>,
#   <User [douglaslira:Douglas Lira]>,
#   <User [kessiacastro:Késsia Castro]>,
#   <User [ovictoraurelio:Victor Aurélio]>,
#   <User [andresmachado:Andre Machado]>,
#   <User [embs:embs]>,
#   <User [tomersimis:Tomer Simis]>,
#   <User [marcellustavares:Marcellus Tavares]>,
#   <User [victorcarrico:Victor Carriço Santos]>,
#   <User [tarcisio-marinho:Tarcísio Marinho]>,
#   <User [filipevarjao:Filipe Varjão]>,
#   <User [iagobelo:Iago Belo]>,
#   <User [thiagoarrais:Thiago Arrais]>,
#   <User [deyvisonrocha:Deyvison Rocha]>,
#   <User [patrickrbc:Patrick Costa]>,
#   <User [alexpessoajr:Alex Pessoa]>,
#   <User [brunolimawd:Bruno Lima]>,
#   <User [arthurmichel:Arthur Michel]>,
#   <User [brunnogomes:Brunno Gomes]>,
#   <User [irgmedeiros:Igor Medeiros]>,
#   <User [Cisneiros:Alexandre Cisneiros]>,
#   <User [mauriciomanoel:Maurício Manoel]>,
#   <User [mayrarabelo:Mayra Rabelo]>,
#   <User [akshaykarle:Akshay Karle]>,
#   <User [lhaisrs:Lhaís Rodrigues]>,
#   <User [ramonsantos:Ramon Santos]>,
#   <User [HaysaRodrigues:Haysa Rodrigues]>,
#   <User [victorfsf:Victor Ferraz]>,
#   <User [tuliohmendes:Túlio Hoffimann]>,
#   <User [leopoldomt:Leopoldo Teixeira]>,
#   <User [yelken:Yelken Gonzales]>,
#   <User [LeonardoGaldino:Leonardo Galdino]>,
#   <User [Juniorlimaivd:Júnior Lima]>,
#   <User [JoaoGFarias:João Farias]>,
#   <User [paulolieuthier:Paulo Lieuthier]>,
#   <User [pereiragislene:Gislene Pereira]>,
#   <User [dayvsonlima:Dayvson Lima]>,
#   <User [fchicout:Fábio Chicout]>,
#   <User [lmarinho:Lucas Marinho]>,
#   <User [jayralencar:Jayr Alencar]>,
#   <User [frankjuniorr:Frank Junior]>,
#   <User [felipefarias:Felipe Farias]>,
#   <User [mateusrevoredo:Mateus Revoredo]>,
#   <User [arthurms:Arthur Santos]>,
#   <User [itsmealves:Gabriel Alves]>,
#   <User [meiralins:Hélio Meira Lins]>,
#   <User [t0rr3sp3dr0:Pedro Tôrres]>,
#   <User [RodrigoCastiel:Rodrigo Castiel]>,
#   <User [hamorim:Hugo Amorim]>,
#   <User [FranckAJ:Franck Aragão]>,
#   <User [julianalucena:Juliana Lucena]>,
#   <User [casevictor:Victor Casé]>,
#   <User [lipse:Filipe Batista]>,
#   <User [ThaisaMirely:Thaisa Mirely]>,
#   <User [marcosisocram:Marcos Paulo]>,
#   <User [espellcaste:Renato Alves]>,
#   <User [Gustavomagalhaes:Gustavo Magalhães Pereira]>,
#   <User [leticiamachado:Maria Letícia Machado]>,
#   <User [abelb0rges:Abel Borges]>,
#   <User [rpragana:Rildo Pragana]>,
#   <User [WandersonAlves:Wanderson Alves]>,
#   <User [omailson:Mailson Lira]>,
#   <User [rvlb-19:Renato Vieira Leite de Barros]>,
#   <User [mirjahal:Almir Jr.]>,
#   <User [alexjosesilva:Alex José Silva]>,
#   <User [peaonunes:Rafael Nunes]>,
#   <User [matheusmariano:Matheus Mariano]>,
#   <User [inacionery:Inácio Nery]>,
#   <User [daniellqueiroz:Daniel Queiroz Santos]>,
#   <User [andersonresende:Anderson Resende]>,
#   <User [caiobsouza:Caio Souza]>,
#   <User [araujoraphael:Raphael Alves]>,
#   <User [djalmaafilho:Djalma Antonio dos Passos Filho]>,
#   <User [eron93br:eronides neto]>,
#   <User [TigerRobocop:Liv Souza]>,
#   <User [AbrantesMar:Márcio Abrantes]>,
#   <User [thiago-farias:Thiago Farias]>,
#   <User [eduardo-melo:Eduardo]>,
#   <User [gabrieldluca:Gabriel D'Luca]>,
#   <User [herbertt:]>,
#   <User [FranciscoMarinho:Francisco Marinho]>,
#   <User [hugobessa:Hugo Bessa]>,
#   <User [cleydyr:Cleydyr Bezerra de Albuquerque]>,
#   <User [felipedealbuquerque:Felipe de Albuquerque]>,
#   <User [PedroRossi:Pedro Gonçalves Rossi Rodrigues]>,
#   <User [lauromoura:Lauro Moura]>,
#   <User [rodolfoestevam:Rodolfo Estevam ]>,
#   <User [igormp:Igor Moura]>,
#   <User [matheusFTC:Matheus Filipe Teixeira Chaves]>,
#   <User [alvarocavalcanti:Alvaro Cavalcanti]>,
#   <User [rafaprax:Rafael Praxedes]>,
#   <User [leuthier:Victor Leuthier]>,
#   <User [foolOnTheHill:George Oliveira]>,
#   <User [setanta:Marcelo Lira]>,
#   <User [jeftarmascarenhas:Jeftar Mascarenhas]>,
#   <User [joseronierison:José Roniérison]>,
#   <User [eudesll:Eudes Lemos]>,
#   <User [nielsonsantana:Nielson Santana]>,
#   <User [guilhermepaiva:Guilherme Paiva]>,
#   <User [brandizzi:Adam Brandizzi]>,
#   <User [rcaval:Ricardo Cavalcanti]>,
#   <User [pedroqueiroz:Pedro Queiroz ]>,
#   <User [gcaraciolo:Guilherme Caraciolo]>,
#   <User [hpbl:Hilton Pintor]>,
#   <User [oliveriojnn:Olivério Neto]>,
#   <User [alinedoleron:Aline D'Oleron Cantarelli]>,
#   <User [raquelguimaraes:Raquel Guimarães]>,
#   <User [rcbop:Rogério Peixoto]>,
#   <User [rsarai:Rebeca Sarai]>,
#   <User [andreldm:Andre Miranda]>,
#   <User [acmh:Artur Montenegro]>,
#   <User [brunovpl:Bruno Verçosa Pereira Lins]>,
#   <User [rsilvabr:Rodolfo Silva]>,
#   <User [lpmfilho:Luis Medeiros]>,
#   <User [anantpaatra:Anant Paatra]>,
#   <User [cassiolpaixao90:Cassio Paixão]>,
#   <User [atriciasabino:Atrícia Sabino]>,
#   <User [ThiagoAugustoSM:Thiago Augusto]>,
#   <User [alocjr:Antonio Luiz Cavalcanti - Tj]>,
#   <User [amandasavluchinske:Amanda Savluchinske]>,
#   <User [sgosantos:Silvio Gustavo de Oliveira Santos]>,
#   <User [caionovaes:Caio Novaes]>,
#   <User [mabj:Marcos Álvares]>,
#   <User [IFormiga:Igor Formiga]>,
#   <User [esdrascosta:Esdras Costa]>,
#   <User [gabrielteodosio:Gabriel Teodósio Marques de Melo]>,
#   <User [marvinbraga:Marcus Vinicius Braga]>,
#   <User [lucascmelo:Lucas Cavalcanti]>,
#   <User [julihermes:Julihermes Melo]>,
#   <User [Valgueiro:Mateus Valgueiro]>,
#   <User [paulomenezes:Paulo Menezes]>,
#   <User [antoniosj:Antonio Silva Júnior]>,
#   <User [geocarvalho:George Carvalho]>,
#   <User [leonardooo:Leonardo de Assis]>,
#   <User [allanragec:Allan Melo]>,
#   <User [wylliams:Wylliams Barbosa Santos]>,
#   <User [sergiohampel:Sérgio Hampel]>,
#   <User [mulatinho:Alexandre Mulatinho]>,
#   <User [albertmourato:Albertinin Mourato Santos]>,
#   <User [dapine:David]>,
#   <User [hnka:Cecília Hunka]>,
#   <User [flpn:Felipe Netto]>,
#   <User [fltiago:Tiago Ferreira Lima]>,
#   <User [rafoli:Rafael Oliveira]>,
#   <User [ThomazFB:Thomaz de Freitas Barbosa Cortez]>,
#   <User [nivan:Nivan Ferreira]>,
#   <User [lubarinobr:Matheus Lubarino]>,
#   <User [rbrazileiro:rbrz]>,
#   <User [ramon-v:Ramon Vasconcelos]>,
#   <User [leoreinaux:Leandro Reinaux]>,
#   <User [raony:raony araújo]>,
#   <User [Lucas-CardosoO:Lucas Cardoso]>,
#   <User [ericbbraga:Eric Braga]>,
#   <User [AlexSoaresDeSiqueira:Alex Soares de Siqueira]>,
#   <User [pernambucano:Paulo Fernandes]>,
#   <User [thiagoolsilva:thiago lopes silva]>,
#   <User [luizlago:Luiz Augusto Lago]>,
#   <User [JohnsonMauro:Johnson Mauro]>,
#   <User [arineto:Arimatea Neto]>,
#   <User [phbraga:Pedro Henrique Magalhães Braga]>,
#   <User [leonardopaiva:Leonardo Paiva]>,
#   <User [renatoosousa:Renato Sousa]>,
#   <User [juliosmelo:Júlio César Silveira Mélo]>,
#   <User [debscorreia:Débora Correia]>,
#   <User [dnloliveira1:Daniel de Oliveira Silva]>,
#   <User [MarcusDEFGH:Marcus Teixeira]>,
#   <User [gustavomeloGH:Gustavo Melo]>,
#   <User [wwcoderecife:WWcode Recife]>,
#   <User [thiagoprazeres:Thiago Bezerra]>,
#   <User [guilhermebm:Guilherme Barreto]>,
#   <User [douglas-queiroz:Douglas Queiroz]>,
#   <User [andersongns:Anderson Santos]>,
#   <User [cauannelinhares:Cauanne Linhares]>,
#   <User [meirinaldojunior:Meirinaldo Júnior]>,
#   <User [adilsonchacon:Adilson Chacon Cavalcanti]>,
#   <User [citiufpe:CITi]>,
#   <User [Artrogeno:Arthur Costa]>,
#   <User [andreneto:André Carneiro]>,
#   <User [favasconcelos:Felipe Vasconcelos]>,
#   <User [DanBrV:Daniel Veras]>,
#   <User [caiocaladoo:Caio Calado]>,
#   <User [valterh4ck3r:Valter Negreiros]>,
#   <User [bebetocf:Roberto Fernandes]>,
#   <User [tcostam:Tiago Costa]>,
#   <User [dudurocha:Eduardo Rocha]>,
#   <User [hfbassani:Hansenclever Bassani]>,
#   <User [matheuslins:Matheus Lins]>,
#   <User [isabarros:Isadora Barros]>,
#   <User [gpb:Gustavo Pimentel]>,
#   <User [patomarques:Pato Marques]>,
#   <User [filipewl:Filipe W. Lima]>,
#   <User [yeltsin:Yeltsin Lima]>,
#   <User [misawsneto:Misael]>,
#   <User [tmoura10:Thiago Moura]>,
#   <User [penelopearaujo:Penélope Araújo]>,
#   <User [thiago-cavalcanti:Thiago Cavalcanti Pimenta]>,
#   <User [pianolab:PIANOLAB]>,
#   <User [ezequias:Ezequias Rocha]>,
#   <User [marcelogalvao:Marcelo Galvão]>,
#   <User [pcosv:Paula Vaz]>,
#   <User [dennys-bd:Dennys Azevedo]>,
#   <User [andremelo87:Deco Melo]>,
#   <User [igoriols:Igor Oliveira]>,
#   <User [tacionery:Tácio Nery]>,
#   <User [diego1araujo:DIEGO Araujo]>,
#   <User [corallocatelli:Coral Locatelli]>,
#   <User [chicofilho:Francisco Pimentel]>,
#   <User [paulinhoerry:Paulo Rodrigues]>,
#   <User [jpaulorio:João Paulo Leonidas Fernandes Dias da Silva]>,
#   <User [grodrigues:Gustavo Rodrigues]>,
#   <User [johanngomes:Johann Gomes]>,
#   <User [sjcostaneto:Severino Neto (SJCostaNeto)]>,
#   <User [gillianomenezes:Gilliano Menezes]>,
#   <User [lucasbarross:Lucas Barros]>,
#   <User [luishmelo:Luís Melo]>,
#   <User [Masterfoni:João Vitor]>,
#   <User [lvrma:Lucas Valença]>,
#   <User [andersonberg:Anderson Berg]>,
#   <User [AugustoQueiroz:Augusto Queiroz]>,
#   <User [MauricioLimaJR:Mauricio Lima]>,
#   <User [Rafaziz:Rafael Aziz Da Silva Rocha]>,
#   <User [Allansantosdefreitas:Allan Santos]>,
#   <User [lhew:Leonardo Marques]>,
#   <User [jamissonfreitas:Jamisson Santana de Freitas]>,
#   <User [williambeto:José Willams]>,
#   <User [adelmojnr:Adelmo Junior]>,
#   <User [MiniMarvin:Caio Gomes]>,
#   <User [figueredo:Thiago Figueredo Cardoso]>,
#   <User [douglasrangel:Douglas Rangel]>,
#   <User [KewinLima:Kewin Lima Da Silva]>,
#   <User [sfilhu:Sérgio Filho]>,
#   <User [wellington16:Wellington]>,
#   <User [filipeluiz:Filipe Luiz ]>,
#   <User [elidioxg:Elidio Guimaraes]>,
#   <User [aperrelli:Anderson Perrelli]>,
#   <User [brunapvasconcelos:Bruna Vasconcelos]>,
#   <User [franciscoffavaro:Francisco Favaro]>,
#   <User [viniciusgalvao:Vinícius Galvão]>,
#   <User [marcocarnut:Marco Carnut]>,
#   <User [lbrito1:Leonardo Brito]>,
#   <User [ianlucas:Ian Lucas]>,
#   <User [medeirosrod:Rodrigo Medeiros]>,
#   <User [Bonifacio2:Bonifacio de Oliveira]>,
#   <User [camilacnery:Camila Nery]>,
#   <User [fernandopereira:Fernando Pereira]>,
#   <User [thiagotargino:Thiago Targino]>,
#   <User [carvalhodj:Daniel Carvalho]>,
#   <User [diogobrsantos:Diogo Barros]>,
#   <User [paulapithon:Paula Pithon]>,
#   <User [dgmneto:Divino Gervasio de Menezes Neto]>,
#   <User [macm3:Marcela Azevedo]>,
#   <User [davincif:Leonardo Da Vinci]>,
#   <User [lucianowolf:Luciano Wolf]>,
#   <User [filipe0513:Filipe Magalhães]>,
#   <User [daicorrea:Daiane Correa]>,
#   <User [viniciuspolux:Polux]>,
#   <User [felipealencar:Felipe]>,
#   <User [tobiasparaiso:Tobias Paraiso]>,
#   <User [giovannipcarvalho:Giovanni Paolo]>,
#   <User [iagoneresb:Iago Neres]>,
#   <User [luanoliveira1992:Luan Oliveira]>,
#   <User [Vitor0liveira:Vitor Oliveira]>,
#   <User [filipecabraal:Filipe Cabral]>,
#   <User [fjmartins:FJ]>,
#   <User [r4ddek:Leonardo Figueirôa e Silva]>,
#   <User [joelnetodev:Joel Neto]>,
#   <User [estevaocm:Estêvão "Steven" Chaves Monteiro]>,
#   <User [tvarjao:Thiago Varjão]>,
#   <User [kevinbreaker:Kevin Martin]>,
#   <User [palmeidaprog:Paulo Almeida Filho]>,
#   <User [fecalemos:Fernando Lemos]>,
#   <User [fehaa:Fernando Alves]>,
#   <User [rafaelmotaalves:Rafael Mota Alves]>,
#   <User [luizpaulogodoy:Luiz Paulo Godoy]>,
#   <User [joaozig:João Ricardo Bastos]>,
#   <User [fms6:Filipe Melo]>,
#   <User [rennanmoura1990:Rennan Moura]>,
#   <User [romildojuliano:Romildo Juliano]>,
#   <User [rbm4:Ricardo Malafaia]>,
#   <User [ronaldoveras:Ronaldo C. Veras]>,
#   <User [mangueBit:André Luna]>,
#   <User [rhnasc:Renato Nascimento]>,
#   <User [brunosouza:Bruno Souza]>,
#   <User [pethersilva:Pether Silva]>,
#   <User [aeciovc:Aécio]>,
#   <User [brunoassisp:Bruno de Assis Pereira]>,
#   <User [niltonheck:Nilton Heck]>,
#   <User [wagnerpaxs:Wagner Santos]>,
#   <User [soareswallace:Wallace Soares]>,
#   <User [ricardowendell:Ricardo Wendell]>,
#   <User [consensotec:Consenso - Tecnologia da Informação]>,
#   <User [wfsneto:Walmir Neto]>,
#   <User [gppeixoto:Guilherme Peixoto]>,
#   <User [tonidas:Airton Sampaio]>,
#   <User [danielcandidos:Daniel Cândido]>,
#   <User [saulobr88:Saulo Gomes]>,
#   <User [victoraldabalde:Victor Aldabalde]>,
#   <User [Asaffe:ASAFFE]>,
#   <User [alisonamerico:Alison Américo]>,
#   <User [igor-simoes:Igor Simões]>,
#   <User [thiagofranca:Thiago França]>,
#   <User [marcoshmendes:Marcos Mendes]>,
#   <User [adecarli:André De' Carli da Mota Silveira]>,
#   <User [klebercode:Kleber Soares]>,
#   <User [MayaraCastro:Mayara Castro]>,
#   <User [lucianojsjr:Luciano José]>,
#   <User [renvicente:Renan Vicente Da Silva]>,
#   <User [felipemanga:Felipe Manga]>,
#   <User [jctvEC:Juliano Cezar Teles Vaz]>,
#   <User [GabrielAlbq:Gabriel Albuquerque de Oliveira]>,
#   <User [igorgatis:Igor Gatis]>,
#   <User [WilliamRoger:William Roger]>,
#   <User [mauLeal:Maurício Leal Júnior]>,
#   <User [joaoaab:João Assunção]>,
#   <User [luanbrito7:Luan Brito]>,
#   <User [wison27:Vinícius]>,
#   <User [luhanlacerda:Luhan Lacerda]>,
#   <User [netoabel:Abel Neto]>,
#   <User [tancredosouza:Tancredo Souza]>,
#   <User [joelcipriano:Joel Cipriano]>,
#   <User [marcelolima:Marcelo Lima]>,
#   <User [digounet:Pablo Rodrigo]>,
#   <User [soikmd2:Marlon Almeida]>,
#   <User [antoniocorreia:Antonio Correia]>,
#   <User [jmignac:Jesse Mignac]>,
#   <User [eliabejr:Eliabe Júnior]>,
#   <User [leleofg:Leonardo Farias]>,
#   <User [ledebour:Luís Ledebour]>,
#   <User [marlosin:Marlos Borges]>,
#   <User [tpmarcs:Jose Marcilio]>,
#   <User [felipebonezi:Felipe Bonezi]>,
#   <User [phellipealexandre:Phellipe Silva]>,
#   <User [AnnyChien:Anny Chien]>,
#   <User [BernardoHazin:Bernardo Hazin]>,
#   <User [Leviterus:Ramon Wanderley]>,
#   <User [fernandofragoso:Fernando Fragoso]>,
#   <User [DiegoSilva776:Diego Marcolino Silva]>,
#   <User [spider8:Anderson Araújo]>,
#   <User [renatohlf:Renato Henrique]>,
#   <User [jamessonfaria:Jamesson Faria]>,
#   <User [lpmourato:Patricio Mourato]>,
#   <User [mikeliguedes:Mikele Guedes]>,
#   <User [MatheusUehara:Matheus Uehara]>,
#   <User [felipesotero:Luiz Felipe Sotero]>,
#   <User [rodrigoperazzo:Rodrigo Perazzo]>,
#   <User [diogoffmelo:Diogo Felipe Felix de Melo]>,
#   <User [dmente03:Daniel Silvestre]>,
#   <User [jpedrocm:João Pedro Magalhães]>,
#   <User [guilhermebrandao:Guilherme Brandão]>,
#   <User [rmd2:Renato Moura]>,
#   <User [jefferson-lima:Jefferson Alves Lima]>,
#   <User [carlosvictor:Carlos Victor Gomes]>,
#   <User [mariojor:Mario Jorge]>,
#   <User [lapl:Lucas Lima]>,
#   <User [diogo10:Diogo Henrique]>,
#   <User [guilhermejccavalcanti:Guilherme Cavalcanti]>,
#   <User [megazord:Megazord]>,
#   <User [wba25:Wellington Barbosa]>,
#   <User [filipecalegario:Filipe Calegario]>,
#   <User [linhaplana:Caio Menescal]>,
#   <User [ArthurLCastro:Arthur Castro]>,
#   <User [abriela:gabriela]>,
#   <User [Uirado:Uirá Veríssimo]>,
#   <User [DaviBarros:Davi de Barros]>,
#   <User [rafaelroballo:Rafael Roballo Wanderley]>,
#   <User [israeljunior:Israel Júnior]>,
#   <User [crystianwendel:Crystian Wendel Meneses Leão]>,
#   <User [lgallindo:Lucas Gallindo]>,
#   <User [eduardobaia:]>,
#   <User [saulolso:Saulo Lopes]>,
#   <User [neryluc:Lucas Nery]>,
#   <User [feliperfranca:Felipe França]>,
#   <User [Rom7:Romain C. M.]>,
#   <User [pablostellet:Pablo Stellet Dias]>,
#   <User [jamilsonbatista:Jamilson Batista]>,
#   <User [rodrigojulianib:Rodrigo Juliani Barbosa]>,
#   <User [jorgemarc:Jorge Marçal]>,
#   <User [Daanielvb:Daniel Vilas-Boas]>,
#   <User [FredMaranhao:]>,
#   <User [jpedroh:João Pedro Henrique]>,
#   <User [vitordeatorreao:Vítor de Albuquerque Torreão]>,
#   <User [vmms16:Vinicius Mateus]>,
#   <User [geraldo7junior:Geraldo Gomes]>,
#   <User [rafaelfvcs:Rafael F.V.C. Santos]>,
#   <User [ddefb:Diego Bezerra]>,
#   <User [danielfsbarreto:Daniel Barreto]>,
#   <User [jgfn1:José Gerson Fialho Neto]>,
#   <User [SandroSena:Sandro Sena]>,
#   <User [eduardosm7:Eduardo Moura]>,
#   <User [AlaurentinoOfficial:Anderson Laurentino]>,
#   <User [davidrft:David Riff]>,
#   <User [matequeiroz:Mateus Queiroz]>,
#   <User [victoracioli:Victor]>,
#   <User [manoelcyreno:Manoel Filipe Pereira Silva Cyreno]>,
#   <User [sudorafa:Rafa Lima]>,
#   <User [IsmaelGomes:Ismael Gomes da Silva]>,
#   <User [rodrigodma:Rodrigo Melo]>,
#   <User [ivanAndrade:Ivan Andrade]>,
#   <User [thypad:Thyago Porpino]>,
#   <User [frog789:Raphael Almeida]>,
#   <User [jbsn94:Neto Barbosa]>,
#   <User [fabiorecife:Fábio Almeida]>,
#   <User [raphaelmonte:Raphael Monte]>,
#   <User [willfelix:Will Felix]>,
#   <User [victorpluna:Victor Luna]>,
#   <User [pricardoti:Paulo Ricardo]>,
#   <User [walber:Walber Nunes do Amaral]>,
#   <User [10c8:0x77]>,
#   <User [davidhsv:David Vieira]>,
#   <User [LGR3:LGR3]>,
#   <User [rcaferraz:Rodolfo Ferraz]>,
#   <User [danielmedeiros52:Daniel Medeiros]>,
#   <User [MichaelBarney:Michael barney Junior]>,
#   <User [ntocampos:Moisés Neto]>,
#   <User [cinguilherme:Guilherme Carvalho Cintra]>,
#   <User [ianfireman:Ian Fireman]>,
#   <User [wallacethierre:Wallace Thierrre]>,
#   <User [PauloSanches:Paulo Sanches]>,
#   <User [abhnerAraujo:Abhner Araújo]>,
#   <User [MrRickSan:Ricardo Oliveira]>,
#   <User [rafarocha:Rafael Rocha]>,
#   <User [MatheusSouza12:Matheus Souza]>,
#   <User [alexandreclayton:Alexandre Clayton]>,
#   <User [tecavasconcelos:Tereza Vasconcelos]>,
#   <User [aacgn:Antonio Neto]>,
#   <User [flaubert165:Italo Santana]>,
#   <User [marcoscampelo:Marcos Campelo]>,
#   <User [heitorpaceli:Heitor Paceli Maranhão]>,
#   <User [engtom:Everton Gonçalves]>,
#   <User [almdac:Almir M. da Cunha]>,
#   <User [raafaelima:Rafael Lima]>,
#   <User [FranclinC:Franclin Cabral]>,
#   <User [deyvisonbm:Deyvirson Mendonca]>,
#   <User [adjs:Adenilton Silva]>,
#   <User [ThomasSousa96:Thomás Sousa Silva]>,
#   <User [levisaturnino:Levi Saturnino]>,
#   <User [FelipeTrote:Felipe Trote]>,
#   <User [tonnyvx:Antonio Neto]>,
#   <User [raisagalindo:Raísa Galindo]>,
#   <User [bernardomelo:Bernardo Gomes de Melo]>,
#   <User [yeltsinlima:Yeltsin Lima]>,
#   <User [glpibr:Verdanatech Soluções em TI]>,
#   <User [especializa-user:Especializa Treinamentos]>,
#   <User [pedroboudoux:Pedro Boudoux]>,
#   <User [adailsonfilho:Adailson de Castro]>,
#   <User [feliperp-81:Felipe Rodrigues]>,
#   <User [zecafeitosa:Zeca Feitosa]>,
#   <User [diegoferreirati:Diego Ferreira]>,
#   <User [CaioMoraes:Caio Moraes]>,
#   <User [fmm:Filipe Martins]>,
#   <User [Thyerry:Thyerry Nunes]>,
#   <User [lsca:]>,
#   <User [paulobsa:Paulo R. Araújo]>,
#   <User [mangelis:Marcello Medeiros]>,
#   <User [rlom:Róger Luiz]>,
#   <User [roselmamendestw:Roselma Mendes]>,
#   <User [mmfsf:Marcos Miguel]>,
#   <User [ericklucena:Erick Lucena]>,
#   <User [gildoneto:Gildo Neto]>,
#   <User [witerbino:Wallace Viterbino]>,
#   <User [wbgalvao:Wilder B. Galvão]>,
#   <User [giovanebribeiro:Giovane Boaviagem Ribeiro]>,
#   <User [diogo-lins:Diogo Moreira Lins]>,
#   <User [lucasrbk:Lucas Amorim Vasconcelos Torres]>,
#   <User [lacerdamarcelo:Marcelo Lacerda]>,
#   <User [andredm:Andre Diniz]>,
#   <User [eduardoluiz7:Eduardo Luiz Silva]>,
#   <User [jonathasbsouza:Jônathas Souza]>,
#   <User [marlonchalegre:Marlon Chalegre]>,
#   <User [andersonpe:Anderson]>,
#   <User [vinyfalcao:Vinicius Falcão]>,
#   <User [rodrigosiqueiradev:Rodrigo Siqueira]>,
#   <User [angelobrito:Angelo Brito]>,
#   <User [viniciusmsfraga:Vinícius Fraga]>,
#   <User [caiosm1005:Caio Santana Magalhães]>,
#   <User [caiofsr:Caio Fernando]>,
#   <User [llac78:Leopoldo Costa]>,
#   <User [GeneseLessa:Gênese Lessa]>,
#   <User [jfabiofl:Fábio Fernandes]>,
#   <User [thaisabr:Thaís Burity]>,
#   <User [Matheus-Campos:Matheus Campos]>,
#   <User [brunodutra:Bruno Dutra]>,
#   <User [thyagoismael:Thyago Ismael Oliveira da Silva]>,
#   <User [felypenery:Felype Nery]>,
#   <User [thiagohenrique0810:Thiago Henrique]>,
#   <User [eduardolsneto2:Eduardo Leite]>,
#   <User [gustavolopess:Gustavo H. Lopes de Souza]>,
#   <User [jrafaelm:José Rafael Moraes]>,
#   <User [gilesv:Vinícius Giles]>,
#   <User [marconemm:Marcone Melo Mendonça]>,
#   <User [paulofloliveira:Paulo Fernando de Lima Oliveira]>,
#   <User [rafaelgsm:Rafael Montenegro]>,
#   <User [tavlima:Thiago Lima]>,
#   <User [santojon:Jonathan Santos]>,
#   <User [lucasbiagini:Lucas Biagini]>,
#   <User [saulo2:Saulo Medeiros de Araujo]>,
#   <User [phrps:Pedro Henrique Rodrigues Pereira Silva]>,
#   <User [robertoalencar:Roberto Alencar]>,
#   <User [mrrandrade:Marcelo Andrade]>,
#   <User [miguel89:Miguel Amaral]>,
#   <User [leimig:Higgor Leimig]>,
#   <User [franchenstein:Daniel K. Franch]>,
#   <User [hugoesb:Hugo Salvador]>,
#   <User [pedrodiamel:Pedro Diamel Marrero Fernández]>,
#   <User [jcrbsa:Richardson Bruno]>,
#   <User [izaiasavila:Izaias Ávila C. Filho]>,
#   <User [renatofilho:Renato Araujo Oliveira Filho]>,
#   <User [pabloreis:Pablo Reis de Queiroz]>,
#   <User [SamuelRocha2015:Samuel Rocha]>,
#   <User [brunohoppe:brunohoppe]>,
#   <User [irixs:Íris Soares]>,
#   <User [bcgs:Bruno César]>,
#   <User [Augusto94:]>,
#   <User [danilosoares:Danilo Soares]>,
#   <User [erickapsilva:Ericka Pricila]>,
#   <User [LukPOD1:José Lucas Alves da Silva]>,
#   <User [vitorbc:Vitor Costa]>,
#   <User [brunolrb:Bruno Leonardo Rodrigues Barros]>,
#   <User [joaoferreirape:João Ferreira]>,
#   <User [jonathan-silva:Jonathan Silva]>,
#   <User [johnmaykbrito:John Lima]>,
#   <User [julioamorim:Júlio Amorim]>,
#   <User [amavlopes:Amanda Avelino]>,
#   <User [fareias:Fernando Areias]>,
#   <User [Jnailson:José Nailson B. Santos]>,
#   <User [tiagotrigo:Trigo]>,
#   <User [alexodrosgomes:Alex Sandro Gomes]>,
#   <User [sabrinandrade:Sabrina Andrade]>,
#   <User [wagnerbeethoven:Wagner Beethoven]>,
#   <User [filipecmedeiros:Filipe Medeiros]>,
#   <User [nvsfs:Natália Souza]>,
#   <User [manunejaim:Manuella]>,
#   <User [wtmf:]>,
#   <User [joseviccruz:José Victor Cruz]>,
#   <User [italolemos:Ítalo Lemos]>,
#   <User [felipemobile:Felipe Andrade]>,
#   <User [feliciosan:Felício Santos]>,
#   <User [AdeildoNeto:Adeildo Neto]>,
#   <User [jhdavino:j.h.davino]>,
#   <User [felipeisidorio:Felipe Isidorio]>,
#   <User [mfeitosa:Michael Feitosa]>,
#   <User [josealbino:Jose Albino da Silva Neto]>,
#   <User [afelipefernandes:Felipe Fernandes]>,
#   <User [jbjj:Joabe Jesus]>,
#   <User [ricardo7cordas:Ricardo Freitas]>,
#   <User [ArthurLapprand:Arthur Lapprand]>,
#   <User [mateusnbm:Mateus]>,
#   <User [joaosantana:João Santana]>,
#   <User [walterjardim:Walter Jardim]>,
#   <User [jonathantsilva:]>,
#   <User [SilvaDecio:Décio Silva]>,
#   <User [wagnerbit:Wagner Bitencourt Alves]>,
#   <User [fraposo:Fernando Raposo]>,
#   <User [tiagofsilva:Tiago Farias]>,
#   <User [pnasc:Paulo Nascimento]>,
#   <User [BAMoreira:Bernardo de Azevedo Moreira]>,
#   <User [assj:Airton Soares Júnior]>,
#   <User [Wms5:Wilkinson Maciel]>,
#   <User [prximenes:Pedro Ximenes]>,
#   <User [marlom-jobsom:Marlom Oliveira]>,
#   <User [mayarajuvencio:Mayara Juvêncio da Silva Gomes]>,
#   <User [brnathanlima:Nathanael Lima]>,
#   <User [DyogoViana:Dyogo Viana]>,
#   <User [rodrigoal:Rodrigo Lobo]>,
#   <User [albinojunior:Albino Júnior]>,
#   <User [rodolfops:Rodolfo Pereira Saturnino]>,
#   <User [tuliocpbs:Tulio Cesar]>,
#   <User [EdmilsonSantana:Edmilson Santana]>,
#   <User [alicexmelo:Alice Melo]>,
#   <User [denissonsantos:Denisson Santos]>,
#   <User [manoelamorimneto:Manoel Amorim Neto]>,
#   <User [rhuandantas:Rhuan Dantas]>,
#   <User [carloseachaves:Carlos Chaves]>,
#   <User [danilocostak5:Danilo Pereira]>,
#   <User [cafmf:Carlos Alberto Fortunato]>,
#   <User [GabrielLourenco:Gabriel Lourenço]>,
#   <User [AlexandreDiegoS:Alexandre Diego]>,
#   <User [romagueralima:Arthur Lima]>,
#   <User [felipebelucena:Felipe Lucena]>,
#   <User [magalhaesrebecca:RebeccaM]>,
#   <User [tiagohas:Tiago Henrique]>,
#   <User [Kassio-Ferreira:Kássio Camelo Ferreira da Silva]>,
#   <User [diegobarcelar:Diego Barcelar]>,
#   <User [felipemarques8:Felipe Marques]>,
#   <User [marcelopita:Marcelo Pita]>,
#   <User [kepa:Lucas Lucena Falbo]>,
#   <User [dcaragao:Diego]>,
#   <User [koodaa:koda]>,
#   <User [wesleygcs:Wesley Gabriel Cardozo dos Santos]>,
#   <User [moisespalma:Moisés Simões]>,
#   <User [karollmm:Karoll Melo]>,
#   <User [pedrovsra:Pedro Tiago Araújo]>,
#   <User [filipe-torres:Filipe Torres]>,
#   <User [AleffSouza:Aleff Souza]>,
#   <User [joaopaulosama:João Paulo Santos]>,
#   <User [agcloud:Agência Cloud]>,
#   <User [giuliosa:Giulio Caetano Pires de Sá]>,
#   <User [DwarfThief:Brenno Barboza]>,
#   <User [edfcsx:Eduardo Cipriano]>,
#   <User [daniloBlera:Danilo Blera]>,
#   <User [jessica-rmo:Jéssica Oliveira]>,
#   <User [ruamberg:Ruamberg Vasconcelos Aguiar]>,
#   <User [edigomes:Edimário Gomes]>,
#   <User [udfds:Husky]>,
#   <User [jean-rar:Jean do Nascimento]>,
#   <User [UdneyCarvalho:Udney Carvalho]>,
#   <User [pdraguiar:Pedro Aguiar]>,
#   <User [tomazhawkjr:Tomaz de Aquino]>,
#   <User [madytorres:Madyana Torres]>,
#   <User [lucdias:Lucas Dias Maciel]>,
#   <User [andreximenes:Andre Luiz Ximenes G. da Luz]>,
#   <User [EduardoLisb:Eduardo Lisbôa]>,
#   <User [atailton:Atailton Tavares]>,
#   <User [andrebuarque:André Buarque]>,
#   <User [VanessaVieiraVV:Vanessa Vieira]>,
#   <User [rcbpeixoto:Rogério Peixoto]>,
#   <User [giuliocc:Giulio Carvalho]>,
#   <User [jeronimonascimento:Jerônimo do Nascimento]>,
#   <User [antonioaurel:Antonio ]>,
#   <User [Edgleyson:Edgleyson Menezes]>,
#   <User [guinetik:Joao Guilherme]>,
#   <User [netuh:Netuh]>,
#   <User [claudvanbarret:Claudivan Barreto]>,
#   <User [rafaelllins:Rafaell Lins]>,
#   <User [MaryCaroline:Mariane Pastor]>,
#   <User [rafaelwms:Rafael WMS]>,
#   <User [PedroRafaelDinizMarinho:Pedro Rafael]>,
#   <User [gdanzi:Gustavo Danzi]>,
#   <User [zearthur99:José Arthur Silveira]>,
#   <User [diegocamara:Diego Luiz]>,
#   <User [fabiorush:Fábio Urquiza]>,
#   <User [CaioMalaquias:Caio Malaquias]>,
#   <User [Galtvan:Marcos Galvão]>,
#   <User [ess2:Egberto Santana]>,
#   <User [hgees:Hericles Escoteiro]>,
#   <User [sergio3010:Sérgio Filho]>,
#   <User [ahyalla:Ahyalla Riceli]>,
#   <User [ericksantana:Erick Santana]>,
#   <User [GutenbergCarlos:Gutenberg Carlos]>,
#   <User [flavioms7:Flavio Miranda]>,
#   <User [larislav:Larissa Barros]>,
#   <User [philorocha:Felipe Vieira da Rocha]>,
#   <User [raphalencar:Raphael Brito Alencar]>,
#   <User [heldermccartney:Helder McCartney]>,
#   <User [guilherme-rdnascimento:Guilherme Nascimento]>,
#   <User [ricardorobson:Ricardo Robson]>,
#   <User [PedroHPVieira:Pedro Vieira]>,
#   <User [HuanChristopher:Huan Christopher]>,
#   <User [maysaborges:Maysa Borges]>,
#   <User [brunofalc:Bruno Falcão]>,
#   <User [klaytoncavalcante:Klayton Cavalcante]>,
#   <User [viniciosarodrigues:Vinícios A. Rodrigues]>,
#   <User [LucasFranciscoCorreia:Lucas Francisco Correia]>,
#   <User [janiosarmento:Janio Sarmento]>,
#   <User [PunishedBois:Matheus Ferreira]>,
#   <User [modcs:MoDCS Research Group]>,
#   <User [cristinesereno:Cristine Sereno]>,
#   <User [aquelefelipe:Felipe Figueiroa]>,
#   <User [atilarec:Atila Bezerra ]>,
#   <User [chgsilva:Carlos Henrique]>,
#   <User [anderssonmelo:Andersson Melo]>,
#   <User [alessandrofls:Alessandro Lima]>,
#   <User [GabrielGouv:J. Gabriel Gouveia]>,
#   <User [yalves8:Yasmin ALves]>,
#   <User [DataPE:DataPE]>,
#   <User [marcoscardoso:Marcos Cardoso]>,
#   <User [AvelinoGomez:Avelino Gomez Alonso Jr]>,
#   <User [marcosguedes01:Marcos Guedes]>,
#   <User [raissaguimaraes:Raíssa Guimarães]>,
#   <User [fhenriquecm:Flávio Macedo]>,
#   <User [pabhen:Pablo Henrique]>,
#   <User [warkentien2:Philip Warkentien II]>,
#   <User [marchesin:Anderson Marchesin]>,
#   <User [GPrimow:Gabriel Primo]>,
#   <User [AleffHenrique:Aleff Henrique]>,
#   <User [felipebagetti:Felipe Bagetti]>,
#   <User [borgiani:Felipe Borgiani]>,
#   <User [fabiolindemberg:Fabio Lindemberg]>,
#   <User [shoesthe6:Carlos Felipe]>,
#   <User [Gvascons:João Gabriel de Araújo Vasconcelos]>,
#   <User [dellanio:Dellanio Alencar]>,
#   <User [manoelfneto:Manoel Freitas]>,
#   <User [diasflp:Felipe Dias]>,
#   <User [Eviomarcio:]>,
#   <User [andredidier:André Didier]>,
#   <User [xfernando:Fernando Calheiros]>,
#   <User [ronneyluan:Ronney Bezerra]>,
#   <User [MORDC:Marcos André]>,
#   <User [hsaboya:Henrique Saboya]>,
#   <User [roMendes:Rosangela Mendes]>,
#   <User [WillyNelson:Anivaldo Junior]>,
#   <User [dayvisons:Dayvison Santos]>,
#   <User [daaysesouza:Dayse Souza]>,
#   <User [MarcoAurello:Marco Aurellio]>,
#   <User [betocabus:Alberto Cabús Junior]>,
#   <User [esdrascavalcs:Esdras Cavalcanti]>,
#   <User [betegelse:]>,
#   <User [gampeixoto:Gabriel Peixoto]>,
#   <User [dashdanilo:]>,
#   <User [KLEITONFREITAS:KF]>,
#   <User [pedrocab:Cab]>,
#   <User [mairaaraujo:Maíra Araújo]>,
#   <User [vbsilva:Vinicius Bezerra A. da Silva]>,
#   <User [allandoamaral:Allan do Amaral]>,
#   <User [wendeldesouza:wendell]>,
#   <User [thiagogalvao:Thiago]>,
#   <User [daidson:Daidson Fonseca Alves]>,
#   <User [Andre-dam:André Damázio]>,
#   <User [alanav120:Alana Vieira ]>,
#   <User [luizhsbrito:Luiz Brito]>,
#   <User [diegoMSilva:Diego]>,
#   <User [andrefilipesz:André Filipe]>,
#   <User [FilipelIOn:Filipe Lima]>,
#   <User [guuhh:Gustavo Rodrigues]>,
#   <User [henriquemc:Luiz Henrique Moura Carvalho]>,
#   <User [VictorMouraz:Victor Moura]>,
#   <User [dieggop:Dieggo Carrilho]>,
#   <User [rodrigolinsr:Rodrigo Lins]>,
#   <User [omarpta:Omar Torres]>,
#   <User [petermademann:Peter Mademann]>,
#   <User [japakr:Geovane Júnior]>,
#   <User [alinnepriscila:Alinne Priscila]>,
#   <User [tulliusvinicius:Tullius]>,
#   <User [draraujoo:Demóstenis RIbeiro de Araujo VIllar]>,
#   <User [vinimoraesrc:Vinícius de Moraes Rêgo Cousseau]>,
#   <User [galegostigma:Galego Stigma]>,
#   <User [yeltsinxyz:Yeltsin Lima]>,
#   <User [washingtonferreira:Washington Ferreira]>,
#   <User [jonatascp:Jônatas Cavalcanti Pereira]>,
#   <User [jonolo6:Jonas Olofsson]>,
#   <User [alnp:Alessandra Pereira]>,
#   <User [diogocaetano:Diogo Caetano Alves Firmo]>,
#   <User [daniellyqueiroz:Danielly Queiroz]>,
#   <User [fjuriolli:Fernando Juriolli]>,
#   <User [DaviBFarias:DB Farias]>,
#   <User [ajgan:Antonio Gadelha]>,
#   <User [itsCleyton:Cleyton C.]>,
#   <User [jvog:José Vogeley Alves de Sá]>,
#   <User [SirLVF:Lindeberg Vital de Freitas]>,
#   <User [brfael:RAFAEL DE LUCENA FALCÃO]>,
#   <User [pedrojsn96:]>,
#   <User [lucianasilva:Luciana Maria de Araújo Silva]>,
#   <User [leoomelo:Leonardo Melo]>,
#   <User [lmyboy:Lucas Cavalcanti]>,
#   <User [slunart:Samuel Martins]>,
#   <User [EwertonQueiroz:Ewerton]>,
#   <User [WesleyJw:Wesley Lima]>,
#   <User [euclidesgc:Euclides G. Catunda]>,
#   <User [matheusmmx:Matheus]>,
#   <User [caiochagas:Caio Chagas]>,
#   <User [dpm-cin:Diogo Morais]>,
#   <User [acaxon:Antonio Carlos Amaral]>,
#   <User [hfcamilo:Hugo Felipe Camilo]>,
#   <User [rnns:Rafael Nunes Machado]>,
#   <User [aeciojr:Aécio Júnior]>,
#   <User [buarquepedro:Pedro Buarque]>,
#   <User [monteiro-luiz:Luiz Monteiro]>,
#   <User [gugacarvalho:Guga Carvalho]>,
#   <User [rcananea:Ronaldo Cananéa]>,
#   <User [andersongimino:Anderson Gimino]>,
#   <User [joaoluizdhv:João Luiz D. H. Valença]>,
#   <User [albjoaov:João Victor]>,
#   <User [marcomachado:Marco André Machado]>,
#   <User [xewertonfilipe:Ewerton Filipe]>,
#   <User [EduardoAmaral:Eduardo Fabricio Santana do Amaral]>,
#   <User [elloserafim:Ello Oliveira]>,
#   <User [WilbertoFilho:Wilberto Filho]>,
#   <User [Edy8123:Edyniesky Ferrer]>,
#   <User [84PC04:Prisciliano Costa]>,
#   <User [belcsantiago:Isabel Santiago]>,
#   <User [feliperfmarques:Felipe Marques]>,
#   <User [felipedemacedo:Felipe de Macêdo]>,
#   <User [Gabisampaio:Gabriela Sampaio]>,
#   <User [paguso:Paulo Fonseca]>,
#   <User [lfcdsg88:Luiz Fernando Gomes]>,
#   <User [orlandoaceto:Orlando Verdasca Aceto]>,
#   <User [diegotsouza83:Diego Souza]>,
#   <User [LABCEUS:Laboratório de Cidades Sensitivas]>,
#   <User [denisreis:Denis Reis]>,
#   <User [zLimaa:Ricardo Lima]>,
#   <User [itamarsilva:Itamar Silva]>,
#   <User [flaviohmaia:Flavio Maia]>,
#   <User [altemberg:Altemberg Andrade]>,
#   <User [absilva:Alex Batista]>,
#   <User [gan640:Gabriel Bortoloto]>,
#   <User [rodrigoaccountaccenture:Rodrigo B. Cavalcanti]>,
#   <User [apfmiranda:Alexandre]>,
#   <User [lflucasferreira:Lucas Ferreira]>,
#   <User [andalvalmeida:André Almeida]>,
#   <User [RobsonMarinho:Robson Marinho]>,
#   <User [josenetome:José Neto]>,
#   <User [sofiagalvao:Sofia Galvão]>,
#   <User [igoleo:Igor Gomes]>,
#   <User [ioram7:Ioram Sette]>,
#   <User [JPMagalhaes:JP Magalhaes]>,
#   <User [vitorcruz8621:Vitor Cruz]>,
#   <User [AdoniasBarros:Adonias Barros]>,
#   <User [UmbertoB:]>,
#   <User [klaytondeoliveira:Klayton de Oliveira]>,
#   <User [renatalourena:]>,
#   <User [matheusqfs:Matheus Feitosa]>,
#   <User [krixapolinario:Krix Apolinário]>,
#   <User [ricardovasc:Ricardo Vasconcelos]>,
#   <User [thiagolins:Thiago Lins]>,
#   <User [NthlLima:Nathalia Lima]>,
#   <User [EduardoFreit:Luiz Eduardo Pessoa de Freitas]>,
#   <User [charles-alves:Charles Siqueira Alves]>,
#   <User [RodrigoRodrigues7:Rodrigo Rodrigues]>,
#   <User [wlcosta:Willams de Lima]>,
#   <User [andreporto:André Porto]>,
#   <User [eratsu:Guilherme Lins]>,
#   <User [robsonribeiros:Robson Ribeiro]>,
#   <User [mateus-nascimento:mateus nascimento]>,
#   <User [brunobpb:Bruno Braga]>,
#   <User [uillaneduardo:Uillan Eduardo]>,
#   <User [MartinsMateus:Mateus Martins]>,
#   <User [FlavioCastroFilho:Flavio Castro]>,
#   <User [lrsilva:Leandro Silva]>,
#   <User [keywilliams:Key Williams]>,
#   <User [WallaceRocha:Wallace Rocha]>,
#   <User [julianophp:Juliano Mesquita dos Santos]>,
#   <User [cleytonfar:cleyton_farias]>,
#   <User [augustolimasilva:Augusto Lima da Silva]>,
#   <User [peedrogabriel:Pedro_Lima]>,
#   <User [VictorManoel:Victor Manoel]>,
#   <User [Tiagoemerenciano:Tiago Emerenciano]>,
#   <User [hrmd:Hugo Daher]>,
#   <User [arthur-rizzo:Arthur Rizzo]>,
#   <User [diogoan:Diogo Nóbrega]>,
#   <User [rpss2:Ramom Pereira]>,
#   <User [wsena:Wanessa Sena]>,
#   <User [JamessonCheron:Jamesson Cheron]>,
#   <User [Italord0:Italo Melo]>,
#   <User [tantodom:TantoDom Comunicação]>,
#   <User [rcursino:Rodrigo Cursino]>,
#   <User [sheylacanutobf:Sheyla Canuto]>,
#   <User [walfredosa:Walfredo de Sá]>,
#   <User [igorhlucenaa:Igor Lucena]>,
#   <User [ricardoebbers:Ricardo Ebbers]>,
#   <User [tiagonog:Tiago Nogueira]>,
#   <User [JeffersonLPLima:Jefferson Luiz Pessoa Lima]>,
#   <User [joaopaulogf:joão]>,
#   <User [tuliocrr:Túlio Carvalho]>,
#   <User [hmilena:Mia]>,
#   <User [caioamorim031:Caio Amorim]>,
#   <User [reforcomestrado2015:Grupo 2 - Disciplina de Engenharia de Software Mestrado Profissional]>,
#   <User [ebl4:Edson]>,
#   <User [adozrocha:Ado Rocha]>,
#   <User [Fabio-Lins:Fábio lins]>,
#   <User [empacto:Empacto ]>,
#   <User [cassiorsfreitas:Cássio Freitas]>,
#   <User [iurylira:Iury Lira Ribeiro]>,
#   <User [HerlonNascimento:Herlon Nascimento]>,
#   <User [TCezarRod:Thalles Cezar]>,
#   <User [GabrielaMattias:Gabriela Matias]>,
#   <User [hugosteixeira:Hugo Teixeira]>,
#   <User [mattvie:Mateus Viégas]>,
#   <User [brunoeee:Bruno Magalhães]>,
#   <User [rodrigomuribec:Rodrigo Lins Rodrigues]>,
#   <User [evandroabreu:Evandro Sousa de Abreu]>,
#   <User [sunr00t:Bruno Nascimento]>,
#   <User [angelamcosta:Angela Lima]>,
#   <User [dolalima:Dola]>,
#   <User [andreguigo:André Albuquerque]>,
#   <User [felipemdmelo:Felipe Melo]>,
#   <User [AdrianoDayvson:Adriano Dayvson]>,
#   <User [DoodleWeb:DoodleWeb]>,
#   <User [cirg-upe:Computational Intelligence Research Group - University of Pernambuco]>,
#   <User [hugonmelo:Hugo Melo]>,
#   <User [victor-cortez:Victor Cortez]>,
#   <User [valongueiro:André Valongueiro]>,
#   <User [dofobatista:Rodolfo Batista do Espírito Santo]>,
#   <User [rfccg:Rafael Gouveia]>,
#   <User [gertmuller88:Gert Müller]>,
#   <User [FernandoRLCruz:fernando cruz]>,
#   <User [iatj:IvanT]>,
#   <User [haroldogondim:Haroldo Gondim]>,
#   <User [andreleitao:Andre Leitao]>,
#   <User [islanilton:Islanilton Rodrigues]>,
#   <User [rodrigoadamski:Rodrigo Adamski]>,
#   <User [lucaspcburgos:Lucas Burgos]>,
#   <User [sccrn:Samanta Coutinho]>,
#   <User [LDGNeto:Leonilde Diogenes Gurgel Neto]>,
#   <User [kevenleone:Keven Leone]>,
#   <User [lericardolima:Ricardo Lima]>,
#   <User [sandrocavalcanti:Sandro Cavalcanti]>,
#   <User [erikcordeiro:Éric Cordeiro]>,
#   <User [dmfilho:Dimas Melo Filho]>,
#   <User [cleniomendes:Clenio Mendes]>,
#   <User [feliperod:Felipe Rodrigues]>,
#   <User [AlefRGamer:Alef Ronaldo Palmeira dos Santos]>,
#   <User [igorsimoes:Igor Simões]>,
#   <User [fdsadat:Felipe Duarte de Santana]>,
#   <User [PauloAlves3486:Paulo Alves]>,
#   <User [brenodvs:Breno de Vasconcelos Santos]>,
#   <User [wizdow:Jair Medeiros Ferreira Filho]>,
#   <User [carlosliracl:Carlos Lira]>,
#   <User [DodoAz:Douglas Azevedo Pereira Dantas]>,
#   <User [sjcleao:Sergio Leao]>,
#   <User [douglasbrandao00:Douglas Willian de Farias Brandão]>,
#   <User [BrunoBA:Bruno Barros]>,
#   <User [zchronoz:Gabriel Vasconcelos]>,
#   <User [leolsrd:Léo Lourenço Santa Rosa Dutra]>,
#   <User [FernandaLandim:Fernanda Granja Landim]>,
#   <User [anakcampelo:Ana Katarina Campelo]>,
#   <User [marcelotheodoro:Marcelo Theodoro]>,
#   <User [grfneto:]>,
#   <User [gabrielbazante:Gabriel Bazante]>,
#   <User [petrusaugusto:Petrus Augusto]>,
#   <User [madsonmuller:Madson Muller]>,
#   <User [staylward:]>,
#   <User [aht360:Augusto Henriques Terra]>,
#   <User [guilhermegomes01:Guilherme Gomes]>,
#   <User [RichardSilva12:Richard Silva]>,
#   <User [hcaula:Henrique Caúla]>,
#   <User [brazsandro:Sandro Braz]>,
#   <User [rfccn:Ricardo Ferreira da Costa Campos Neto]>,
#   <User [claudiopacheco:Claudio Pacheco]>,
#   <User [jimens:Jimens Lima]>,
#   <User [deyvisonrochaidealizza:Deyvison Rocha]>,
#   <User [jalexc:Alex Carneiro]>,
#   <User [vmoliveira91:Vitor Oliveira]>,
#   <User [gtgsantos:Guilherme Santos]>,
#   <User [netoffdf:Francisco Dias]>,
#   <User [filipeaguiar:Filipe Aguiar]>,
#   <User [pedrohub:Pedro Edson]>,
#   <User [vandialves:Vandi Alves]>,
#   <User [cesarsantana2:César Santana]>,
#   <User [carlosmax:Carlos Max]>,
#   <User [lauriavictor7:]>,
#   <User [SoulFlybr:João Gabriel]>,
#   <User [fernandohenriqueguimaraes:Fernando Henrique Guimarães]>,
#   <User [eduardascharnhorst:]>,
#   <User [flavindias:Flaviano Dias]>,
#   <User [MateusLoureiro:Mateus Loureiro]>,
#   <User [tamiresa:Tamires Agripino ]>,
#   <User [mcdsb:Mônica Crystine da Silva Bezerra]>,
#   <User [batebit:Batebit Artesania Digital]>,
#   <User [juniorbrasil:Junior Brasil]>,
#   <User [deisesouza:Deise Souza]>,
#   <User [RenatoRJF:Renato Ferreira]>,
#   <User [joaovictortinoco:João Victor Tinoco]>,
#   <User [GabrielSDG:Gabriel D'Emery]>,
#   <User [gabrielteotonio:Gabriel Teotonio]>,
#   <User [marcuscarneiro:Marcus Carneiro]>,
#   <User [EBDAF1:Eraldo Barbosa dos Anjos Filho]>,
#   <User [diegomarinho:Diego Marinho]>,
#   ...]]

# %% [markdown]
# ## ghusers_batches (gh.search_users()) / full_ghusers_batches (gh.user())
# ![image.png](attachment:image.png)

# %%
full_ghusers_batches[0]
# Out:
# [<User [tarruda:Thiago de Arruda]>,
#  <User [mairatma:Maira Bello]>,
#  <User [joselitojunior1:Joselito]>,
#  <User [marcelcaraciolo:Marcel]>,
#  <User [luanfonceca:Luan Fonseca]>,
#  <User [deividazevedo2:Deivid Azevedo]>,
#  <User [simoneas02:Simone Amorim]>,
#  <User [gileno:Gileno Filho]>,
#  <User [filipeximenes:Filipe A Ximenes]>,
#  <User [renatooliveira:Renato Oliveira]>,
#  <User [luiztiago:Luiz Tiago Oliveira]>,
#  <User [ac-pm:acpm]>,
#  <User [fernandocastor:Fernando Castor]>,
#  <User [henvic:Henrique Vicente]>,
#  <User [clovisdasilvaneto:Clóvis Neto]>,
#  <User [fjsj:Flávio Juvenal da Silva Junior]>,
#  <User [zimmerle:Felipe Zimmerle]>,
#  <User [adrielcafe:Adriel Café]>,
#  <User [talitaoliveira:Talita Oliveira]>,
#  <User [arthuralvim:Arthur Alvim]>,
#  <User [paulorec:Paulo Amorim]>,
#  <User [dmesquita:Déborah Mesquita]>,
#  <User [ktquez:Alan Ktquez]>,
#  <User [guilhermefarias:Guilherme Farias]>,
#  <User [brunofarache:Bruno Farache]>,
#  <User [lailsonbm:Lailson Bandeira]>,
#  <User [lmmenge:Lucas Menge]>,
#  <User [brunobasto:Bruno Basto]>,
#  <User [guiocavalcanti:Guilherme Cavalcanti]>,
#  <User [pcstl:Pedro Castilho]>,
#  <User [roselmamendes:Roselma Mendes]>,
#  <User [horaciojcfilho:Horácio Filho]>,
#  <User [dakerfp:Daker Fernandes Pinheiro]>,
#  <User [caiorss:Caio Rordrigues]>,
#  <User [interaminense:Adriano]>,
#  <User [victorlaerte:Victor Laerte Oliveira]>,
#  <User [diegocarloslima:Diego Lima]>,
#  <User [miguelarauj1o:Miguel Araújo]>,
#  <User [diegonvs:Diego Nascimento]>,
#  <User [eduardocruz:Eduardo Cruz ]>,
#  <User [henriquemenezes:Henrique Menezes]>,
#  <User [chocoelho:Carlos Coêlho]>,
#  <User [karlafalcao:Karla Falcão]>,
#  <User [thiagodiniz:Thiago Diniz]>,
#  <User [pauloborba:Paulo Borba]>,
#  <User [jonathanslima:Jonathan]>,
#  <User [gallindo:Miguel Angelo]>,
#  <User [andrewesteves:Andrew Esteves]>,
#  <User [vinicius3w:Vinicius Cardoso Garcia]>,
#  <User [vanessa:Vanessa Barreiros]>,
#  <User [jordanamorais:Jordana Morais]>,
#  <User [Suburbanno:Vinicius R]>,
#  <User [gvc:Guilherme Carvalho]>,
#  <User [dvro:Dayvid Victor]>,
#  <User [douglaslira:Douglas Lira]>,
#  <User [kessiacastro:Késsia Castro]>,
#  <User [ovictoraurelio:Victor Aurélio]>,
#  <User [andresmachado:Andre Machado]>,
#  <User [embs:embs]>,
#  <User [tomersimis:Tomer Simis]>,
#  <User [marcellustavares:Marcellus Tavares]>,
#  <User [victorcarrico:Victor Carriço Santos]>,
#  <User [tarcisio-marinho:Tarcísio Marinho]>,
#  <User [filipevarjao:Filipe Varjão]>,
#  <User [iagobelo:Iago Belo]>,
#  <User [thiagoarrais:Thiago Arrais]>,
#  <User [deyvisonrocha:Deyvison Rocha]>,
#  <User [patrickrbc:Patrick Costa]>,
#  <User [alexpessoajr:Alex Pessoa]>,
#  <User [brunolimawd:Bruno Lima]>,
#  <User [arthurmichel:Arthur Michel]>,
#  <User [brunnogomes:Brunno Gomes]>,
#  <User [irgmedeiros:Igor Medeiros]>,
#  <User [Cisneiros:Alexandre Cisneiros]>,
#  <User [mauriciomanoel:Maurício Manoel]>,
#  <User [mayrarabelo:Mayra Rabelo]>,
#  <User [akshaykarle:Akshay Karle]>,
#  <User [lhaisrs:Lhaís Rodrigues]>,
#  <User [ramonsantos:Ramon Santos]>,
#  <User [HaysaRodrigues:Haysa Rodrigues]>,
#  <User [victorfsf:Victor Ferraz]>,
#  <User [tuliohmendes:Túlio Hoffimann]>,
#  <User [leopoldomt:Leopoldo Teixeira]>,
#  <User [yelken:Yelken Gonzales]>,
#  <User [LeonardoGaldino:Leonardo Galdino]>,
#  <User [Juniorlimaivd:Júnior Lima]>,
#  <User [JoaoGFarias:João Farias]>,
#  <User [paulolieuthier:Paulo Lieuthier]>,
#  <User [pereiragislene:Gislene Pereira]>,
#  <User [dayvsonlima:Dayvson Lima]>,
#  <User [fchicout:Fábio Chicout]>,
#  <User [lmarinho:Lucas Marinho]>,
#  <User [jayralencar:Jayr Alencar]>,
#  <User [frankjuniorr:Frank Junior]>,
#  <User [felipefarias:Felipe Farias]>,
#  <User [mateusrevoredo:Mateus Revoredo]>,
#  <User [arthurms:Arthur Santos]>,
#  <User [itsmealves:Gabriel Alves]>,
#  <User [meiralins:Hélio Meira Lins]>,
#  <User [t0rr3sp3dr0:Pedro Tôrres]>,
#  <User [RodrigoCastiel:Rodrigo Castiel]>,
#  <User [hamorim:Hugo Amorim]>,
#  <User [FranckAJ:Franck Aragão]>,
#  <User [julianalucena:Juliana Lucena]>,
#  <User [casevictor:Victor Casé]>,
#  <User [lipse:Filipe Batista]>,
#  <User [ThaisaMirely:Thaisa Mirely]>,
#  <User [marcosisocram:Marcos Paulo]>,
#  <User [espellcaste:Renato Alves]>,
#  <User [Gustavomagalhaes:Gustavo Magalhães Pereira]>,
#  <User [leticiamachado:Maria Letícia Machado]>,
#  <User [abelb0rges:Abel Borges]>,
#  <User [rpragana:Rildo Pragana]>,
#  <User [WandersonAlves:Wanderson Alves]>,
#  <User [omailson:Mailson Lira]>,
#  <User [rvlb-19:Renato Vieira Leite de Barros]>,
#  <User [mirjahal:Almir Jr.]>,
#  <User [alexjosesilva:Alex José Silva]>,
#  <User [peaonunes:Rafael Nunes]>,
#  <User [matheusmariano:Matheus Mariano]>,
#  <User [inacionery:Inácio Nery]>,
#  <User [daniellqueiroz:Daniel Queiroz Santos]>,
#  <User [andersonresende:Anderson Resende]>,
#  <User [caiobsouza:Caio Souza]>,
#  <User [araujoraphael:Raphael Alves]>,
#  <User [djalmaafilho:Djalma Antonio dos Passos Filho]>,
#  <User [eron93br:eronides neto]>,
#  <User [TigerRobocop:Liv Souza]>,
#  <User [AbrantesMar:Márcio Abrantes]>,
#  <User [thiago-farias:Thiago Farias]>,
#  <User [eduardo-melo:Eduardo]>,
#  <User [gabrieldluca:Gabriel D'Luca]>,
#  <User [herbertt:]>,
#  <User [FranciscoMarinho:Francisco Marinho]>,
#  <User [hugobessa:Hugo Bessa]>,
#  <User [cleydyr:Cleydyr Bezerra de Albuquerque]>,
#  <User [felipedealbuquerque:Felipe de Albuquerque]>,
#  <User [PedroRossi:Pedro Gonçalves Rossi Rodrigues]>,
#  <User [lauromoura:Lauro Moura]>,
#  <User [rodolfoestevam:Rodolfo Estevam ]>,
#  <User [igormp:Igor Moura]>,
#  <User [matheusFTC:Matheus Filipe Teixeira Chaves]>,
#  <User [alvarocavalcanti:Alvaro Cavalcanti]>,
#  <User [rafaprax:Rafael Praxedes]>,
#  <User [leuthier:Victor Leuthier]>,
#  <User [foolOnTheHill:George Oliveira]>,
#  <User [setanta:Marcelo Lira]>,
#  <User [jeftarmascarenhas:Jeftar Mascarenhas]>,
#  <User [joseronierison:José Roniérison]>,
#  <User [eudesll:Eudes Lemos]>,
#  <User [nielsonsantana:Nielson Santana]>,
#  <User [guilhermepaiva:Guilherme Paiva]>,
#  <User [brandizzi:Adam Brandizzi]>,
#  <User [rcaval:Ricardo Cavalcanti]>,
#  <User [pedroqueiroz:Pedro Queiroz ]>,
#  <User [gcaraciolo:Guilherme Caraciolo]>,
#  <User [hpbl:Hilton Pintor]>,
#  <User [oliveriojnn:Olivério Neto]>,
#  <User [alinedoleron:Aline D'Oleron Cantarelli]>,
#  <User [raquelguimaraes:Raquel Guimarães]>,
#  <User [rcbop:Rogério Peixoto]>,
#  <User [rsarai:Rebeca Sarai]>,
#  <User [andreldm:Andre Miranda]>,
#  <User [acmh:Artur Montenegro]>,
#  <User [brunovpl:Bruno Verçosa Pereira Lins]>,
#  <User [rsilvabr:Rodolfo Silva]>,
#  <User [lpmfilho:Luis Medeiros]>,
#  <User [anantpaatra:Anant Paatra]>,
#  <User [cassiolpaixao90:Cassio Paixão]>,
#  <User [atriciasabino:Atrícia Sabino]>,
#  <User [ThiagoAugustoSM:Thiago Augusto]>,
#  <User [alocjr:Antonio Luiz Cavalcanti - Tj]>,
#  <User [amandasavluchinske:Amanda Savluchinske]>,
#  <User [sgosantos:Silvio Gustavo de Oliveira Santos]>,
#  <User [caionovaes:Caio Novaes]>,
#  <User [mabj:Marcos Álvares]>,
#  <User [IFormiga:Igor Formiga]>,
#  <User [esdrascosta:Esdras Costa]>,
#  <User [gabrielteodosio:Gabriel Teodósio Marques de Melo]>,
#  <User [marvinbraga:Marcus Vinicius Braga]>,
#  <User [lucascmelo:Lucas Cavalcanti]>,
#  <User [julihermes:Julihermes Melo]>,
#  <User [Valgueiro:Mateus Valgueiro]>,
#  <User [paulomenezes:Paulo Menezes]>,
#  <User [antoniosj:Antonio Silva Júnior]>,
#  <User [geocarvalho:George Carvalho]>,
#  <User [leonardooo:Leonardo de Assis]>,
#  <User [allanragec:Allan Melo]>,
#  <User [wylliams:Wylliams Barbosa Santos]>,
#  <User [sergiohampel:Sérgio Hampel]>,
#  <User [mulatinho:Alexandre Mulatinho]>,
#  <User [albertmourato:Albertinin Mourato Santos]>,
#  <User [dapine:David]>,
#  <User [hnka:Cecília Hunka]>,
#  <User [flpn:Felipe Netto]>,
#  <User [fltiago:Tiago Ferreira Lima]>,
#  <User [rafoli:Rafael Oliveira]>,
#  <User [ThomazFB:Thomaz de Freitas Barbosa Cortez]>,
#  <User [nivan:Nivan Ferreira]>,
#  <User [lubarinobr:Matheus Lubarino]>,
#  <User [rbrazileiro:rbrz]>,
#  <User [ramon-v:Ramon Vasconcelos]>,
#  <User [leoreinaux:Leandro Reinaux]>,
#  <User [raony:raony araújo]>,
#  <User [Lucas-CardosoO:Lucas Cardoso]>,
#  <User [ericbbraga:Eric Braga]>,
#  <User [AlexSoaresDeSiqueira:Alex Soares de Siqueira]>,
#  <User [pernambucano:Paulo Fernandes]>,
#  <User [thiagoolsilva:thiago lopes silva]>,
#  <User [luizlago:Luiz Augusto Lago]>,
#  <User [JohnsonMauro:Johnson Mauro]>,
#  <User [arineto:Arimatea Neto]>,
#  <User [phbraga:Pedro Henrique Magalhães Braga]>,
#  <User [leonardopaiva:Leonardo Paiva]>,
#  <User [renatoosousa:Renato Sousa]>,
#  <User [juliosmelo:Júlio César Silveira Mélo]>,
#  <User [debscorreia:Débora Correia]>,
#  <User [dnloliveira1:Daniel de Oliveira Silva]>,
#  <User [MarcusDEFGH:Marcus Teixeira]>,
#  <User [gustavomeloGH:Gustavo Melo]>,
#  <User [wwcoderecife:WWcode Recife]>,
#  <User [thiagoprazeres:Thiago Bezerra]>,
#  <User [guilhermebm:Guilherme Barreto]>,
#  <User [douglas-queiroz:Douglas Queiroz]>,
#  <User [andersongns:Anderson Santos]>,
#  <User [cauannelinhares:Cauanne Linhares]>,
#  <User [meirinaldojunior:Meirinaldo Júnior]>,
#  <User [adilsonchacon:Adilson Chacon Cavalcanti]>,
#  <User [citiufpe:CITi]>,
#  <User [Artrogeno:Arthur Costa]>,
#  <User [andreneto:André Carneiro]>,
#  <User [favasconcelos:Felipe Vasconcelos]>,
#  <User [DanBrV:Daniel Veras]>,
#  <User [caiocaladoo:Caio Calado]>,
#  <User [valterh4ck3r:Valter Negreiros]>,
#  <User [bebetocf:Roberto Fernandes]>,
#  <User [tcostam:Tiago Costa]>,
#  <User [dudurocha:Eduardo Rocha]>,
#  <User [hfbassani:Hansenclever Bassani]>,
#  <User [matheuslins:Matheus Lins]>,
#  <User [isabarros:Isadora Barros]>,
#  <User [gpb:Gustavo Pimentel]>,
#  <User [patomarques:Pato Marques]>,
#  <User [filipewl:Filipe W. Lima]>,
#  <User [yeltsin:Yeltsin Lima]>,
#  <User [misawsneto:Misael]>,
#  <User [tmoura10:Thiago Moura]>,
#  <User [penelopearaujo:Penélope Araújo]>,
#  <User [thiago-cavalcanti:Thiago Cavalcanti Pimenta]>,
#  <User [pianolab:PIANOLAB]>,
#  <User [ezequias:Ezequias Rocha]>,
#  <User [marcelogalvao:Marcelo Galvão]>,
#  <User [pcosv:Paula Vaz]>,
#  <User [dennys-bd:Dennys Azevedo]>,
#  <User [andremelo87:Deco Melo]>,
#  <User [igoriols:Igor Oliveira]>,
#  <User [tacionery:Tácio Nery]>,
#  <User [diego1araujo:DIEGO Araujo]>,
#  <User [corallocatelli:Coral Locatelli]>,
#  <User [chicofilho:Francisco Pimentel]>,
#  <User [paulinhoerry:Paulo Rodrigues]>,
#  <User [jpaulorio:João Paulo Leonidas Fernandes Dias da Silva]>,
#  <User [grodrigues:Gustavo Rodrigues]>,
#  <User [johanngomes:Johann Gomes]>,
#  <User [sjcostaneto:Severino Neto (SJCostaNeto)]>,
#  <User [gillianomenezes:Gilliano Menezes]>,
#  <User [lucasbarross:Lucas Barros]>,
#  <User [luishmelo:Luís Melo]>,
#  <User [Masterfoni:João Vitor]>,
#  <User [lvrma:Lucas Valença]>,
#  <User [andersonberg:Anderson Berg]>,
#  <User [AugustoQueiroz:Augusto Queiroz]>,
#  <User [MauricioLimaJR:Mauricio Lima]>,
#  <User [Rafaziz:Rafael Aziz Da Silva Rocha]>,
#  <User [Allansantosdefreitas:Allan Santos]>,
#  <User [lhew:Leonardo Marques]>,
#  <User [jamissonfreitas:Jamisson Santana de Freitas]>,
#  <User [williambeto:José Willams]>,
#  <User [adelmojnr:Adelmo Junior]>,
#  <User [MiniMarvin:Caio Gomes]>,
#  <User [figueredo:Thiago Figueredo Cardoso]>,
#  <User [douglasrangel:Douglas Rangel]>,
#  <User [KewinLima:Kewin Lima Da Silva]>,
#  <User [sfilhu:Sérgio Filho]>,
#  <User [wellington16:Wellington]>,
#  <User [filipeluiz:Filipe Luiz ]>,
#  <User [elidioxg:Elidio Guimaraes]>,
#  <User [aperrelli:Anderson Perrelli]>,
#  <User [brunapvasconcelos:Bruna Vasconcelos]>,
#  <User [franciscoffavaro:Francisco Favaro]>,
#  <User [viniciusgalvao:Vinícius Galvão]>,
#  <User [marcocarnut:Marco Carnut]>,
#  <User [lbrito1:Leonardo Brito]>,
#  <User [ianlucas:Ian Lucas]>,
#  <User [medeirosrod:Rodrigo Medeiros]>,
#  <User [Bonifacio2:Bonifacio de Oliveira]>,
#  <User [camilacnery:Camila Nery]>,
#  <User [fernandopereira:Fernando Pereira]>,
#  <User [thiagotargino:Thiago Targino]>,
#  <User [carvalhodj:Daniel Carvalho]>,
#  <User [diogobrsantos:Diogo Barros]>,
#  <User [paulapithon:Paula Pithon]>,
#  <User [dgmneto:Divino Gervasio de Menezes Neto]>,
#  <User [macm3:Marcela Azevedo]>,
#  <User [davincif:Leonardo Da Vinci]>,
#  <User [lucianowolf:Luciano Wolf]>,
#  <User [filipe0513:Filipe Magalhães]>,
#  <User [daicorrea:Daiane Correa]>,
#  <User [viniciuspolux:Polux]>,
#  <User [felipealencar:Felipe]>,
#  <User [tobiasparaiso:Tobias Paraiso]>,
#  <User [giovannipcarvalho:Giovanni Paolo]>,
#  <User [iagoneresb:Iago Neres]>,
#  <User [luanoliveira1992:Luan Oliveira]>,
#  <User [Vitor0liveira:Vitor Oliveira]>,
#  <User [filipecabraal:Filipe Cabral]>,
#  <User [fjmartins:FJ]>,
#  <User [r4ddek:Leonardo Figueirôa e Silva]>,
#  <User [joelnetodev:Joel Neto]>,
#  <User [estevaocm:Estêvão "Steven" Chaves Monteiro]>,
#  <User [tvarjao:Thiago Varjão]>,
#  <User [kevinbreaker:Kevin Martin]>,
#  <User [palmeidaprog:Paulo Almeida Filho]>,
#  <User [fecalemos:Fernando Lemos]>,
#  <User [fehaa:Fernando Alves]>,
#  <User [rafaelmotaalves:Rafael Mota Alves]>,
#  <User [luizpaulogodoy:Luiz Paulo Godoy]>,
#  <User [joaozig:João Ricardo Bastos]>,
#  <User [fms6:Filipe Melo]>,
#  <User [rennanmoura1990:Rennan Moura]>,
#  <User [romildojuliano:Romildo Juliano]>,
#  <User [rbm4:Ricardo Malafaia]>,
#  <User [ronaldoveras:Ronaldo C. Veras]>,
#  <User [mangueBit:André Luna]>,
#  <User [rhnasc:Renato Nascimento]>,
#  <User [brunosouza:Bruno Souza]>,
#  <User [pethersilva:Pether Silva]>,
#  <User [aeciovc:Aécio]>,
#  <User [brunoassisp:Bruno de Assis Pereira]>,
#  <User [niltonheck:Nilton Heck]>,
#  <User [wagnerpaxs:Wagner Santos]>,
#  <User [soareswallace:Wallace Soares]>,
#  <User [ricardowendell:Ricardo Wendell]>,
#  <User [consensotec:Consenso - Tecnologia da Informação]>,
#  <User [wfsneto:Walmir Neto]>,
#  <User [gppeixoto:Guilherme Peixoto]>,
#  <User [tonidas:Airton Sampaio]>,
#  <User [danielcandidos:Daniel Cândido]>,
#  <User [saulobr88:Saulo Gomes]>,
#  <User [victoraldabalde:Victor Aldabalde]>,
#  <User [Asaffe:ASAFFE]>,
#  <User [alisonamerico:Alison Américo]>,
#  <User [igor-simoes:Igor Simões]>,
#  <User [thiagofranca:Thiago França]>,
#  <User [marcoshmendes:Marcos Mendes]>,
#  <User [adecarli:André De' Carli da Mota Silveira]>,
#  <User [klebercode:Kleber Soares]>,
#  <User [MayaraCastro:Mayara Castro]>,
#  <User [lucianojsjr:Luciano José]>,
#  <User [renvicente:Renan Vicente Da Silva]>,
#  <User [felipemanga:Felipe Manga]>,
#  <User [jctvEC:Juliano Cezar Teles Vaz]>,
#  <User [GabrielAlbq:Gabriel Albuquerque de Oliveira]>,
#  <User [igorgatis:Igor Gatis]>,
#  <User [WilliamRoger:William Roger]>,
#  <User [mauLeal:Maurício Leal Júnior]>,
#  <User [joaoaab:João Assunção]>,
#  <User [luanbrito7:Luan Brito]>,
#  <User [wison27:Vinícius]>,
#  <User [luhanlacerda:Luhan Lacerda]>,
#  <User [netoabel:Abel Neto]>,
#  <User [tancredosouza:Tancredo Souza]>,
#  <User [joelcipriano:Joel Cipriano]>,
#  <User [marcelolima:Marcelo Lima]>,
#  <User [digounet:Pablo Rodrigo]>,
#  <User [soikmd2:Marlon Almeida]>,
#  <User [antoniocorreia:Antonio Correia]>,
#  <User [jmignac:Jesse Mignac]>,
#  <User [eliabejr:Eliabe Júnior]>,
#  <User [leleofg:Leonardo Farias]>,
#  <User [ledebour:Luís Ledebour]>,
#  <User [marlosin:Marlos Borges]>,
#  <User [tpmarcs:Jose Marcilio]>,
#  <User [felipebonezi:Felipe Bonezi]>,
#  <User [phellipealexandre:Phellipe Silva]>,
#  <User [AnnyChien:Anny Chien]>,
#  <User [BernardoHazin:Bernardo Hazin]>,
#  <User [Leviterus:Ramon Wanderley]>,
#  <User [fernandofragoso:Fernando Fragoso]>,
#  <User [DiegoSilva776:Diego Marcolino Silva]>,
#  <User [spider8:Anderson Araújo]>,
#  <User [renatohlf:Renato Henrique]>,
#  <User [jamessonfaria:Jamesson Faria]>,
#  <User [lpmourato:Patricio Mourato]>,
#  <User [mikeliguedes:Mikele Guedes]>,
#  <User [MatheusUehara:Matheus Uehara]>,
#  <User [felipesotero:Luiz Felipe Sotero]>,
#  <User [rodrigoperazzo:Rodrigo Perazzo]>,
#  <User [diogoffmelo:Diogo Felipe Felix de Melo]>,
#  <User [dmente03:Daniel Silvestre]>,
#  <User [jpedrocm:João Pedro Magalhães]>,
#  <User [guilhermebrandao:Guilherme Brandão]>,
#  <User [rmd2:Renato Moura]>,
#  <User [jefferson-lima:Jefferson Alves Lima]>,
#  <User [carlosvictor:Carlos Victor Gomes]>,
#  <User [mariojor:Mario Jorge]>,
#  <User [lapl:Lucas Lima]>,
#  <User [diogo10:Diogo Henrique]>,
#  <User [guilhermejccavalcanti:Guilherme Cavalcanti]>,
#  <User [megazord:Megazord]>,
#  <User [wba25:Wellington Barbosa]>,
#  <User [filipecalegario:Filipe Calegario]>,
#  <User [linhaplana:Caio Menescal]>,
#  <User [ArthurLCastro:Arthur Castro]>,
#  <User [abriela:gabriela]>,
#  <User [Uirado:Uirá Veríssimo]>,
#  <User [DaviBarros:Davi de Barros]>,
#  <User [rafaelroballo:Rafael Roballo Wanderley]>,
#  <User [israeljunior:Israel Júnior]>,
#  <User [crystianwendel:Crystian Wendel Meneses Leão]>,
#  <User [lgallindo:Lucas Gallindo]>,
#  <User [eduardobaia:]>,
#  <User [saulolso:Saulo Lopes]>,
#  <User [neryluc:Lucas Nery]>,
#  <User [feliperfranca:Felipe França]>,
#  <User [Rom7:Romain C. M.]>,
#  <User [pablostellet:Pablo Stellet Dias]>,
#  <User [jamilsonbatista:Jamilson Batista]>,
#  <User [rodrigojulianib:Rodrigo Juliani Barbosa]>,
#  <User [jorgemarc:Jorge Marçal]>,
#  <User [Daanielvb:Daniel Vilas-Boas]>,
#  <User [FredMaranhao:]>,
#  <User [jpedroh:João Pedro Henrique]>,
#  <User [vitordeatorreao:Vítor de Albuquerque Torreão]>,
#  <User [vmms16:Vinicius Mateus]>,
#  <User [geraldo7junior:Geraldo Gomes]>,
#  <User [rafaelfvcs:Rafael F.V.C. Santos]>,
#  <User [ddefb:Diego Bezerra]>,
#  <User [danielfsbarreto:Daniel Barreto]>,
#  <User [jgfn1:José Gerson Fialho Neto]>,
#  <User [SandroSena:Sandro Sena]>,
#  <User [eduardosm7:Eduardo Moura]>,
#  <User [AlaurentinoOfficial:Anderson Laurentino]>,
#  <User [davidrft:David Riff]>,
#  <User [matequeiroz:Mateus Queiroz]>,
#  <User [victoracioli:Victor]>,
#  <User [manoelcyreno:Manoel Filipe Pereira Silva Cyreno]>,
#  <User [sudorafa:Rafa Lima]>,
#  <User [IsmaelGomes:Ismael Gomes da Silva]>,
#  <User [rodrigodma:Rodrigo Melo]>,
#  <User [ivanAndrade:Ivan Andrade]>,
#  <User [thypad:Thyago Porpino]>,
#  <User [frog789:Raphael Almeida]>,
#  <User [jbsn94:Neto Barbosa]>,
#  <User [fabiorecife:Fábio Almeida]>,
#  <User [raphaelmonte:Raphael Monte]>,
#  <User [willfelix:Will Felix]>,
#  <User [victorpluna:Victor Luna]>,
#  <User [pricardoti:Paulo Ricardo]>,
#  <User [walber:Walber Nunes do Amaral]>,
#  <User [10c8:0x77]>,
#  <User [davidhsv:David Vieira]>,
#  <User [LGR3:LGR3]>,
#  <User [rcaferraz:Rodolfo Ferraz]>,
#  <User [danielmedeiros52:Daniel Medeiros]>,
#  <User [MichaelBarney:Michael barney Junior]>,
#  <User [ntocampos:Moisés Neto]>,
#  <User [cinguilherme:Guilherme Carvalho Cintra]>,
#  <User [ianfireman:Ian Fireman]>,
#  <User [wallacethierre:Wallace Thierrre]>,
#  <User [PauloSanches:Paulo Sanches]>,
#  <User [abhnerAraujo:Abhner Araújo]>,
#  <User [MrRickSan:Ricardo Oliveira]>,
#  <User [rafarocha:Rafael Rocha]>,
#  <User [MatheusSouza12:Matheus Souza]>,
#  <User [alexandreclayton:Alexandre Clayton]>,
#  <User [tecavasconcelos:Tereza Vasconcelos]>,
#  <User [aacgn:Antonio Neto]>,
#  <User [flaubert165:Italo Santana]>,
#  <User [marcoscampelo:Marcos Campelo]>,
#  <User [heitorpaceli:Heitor Paceli Maranhão]>,
#  <User [engtom:Everton Gonçalves]>,
#  <User [almdac:Almir M. da Cunha]>,
#  <User [raafaelima:Rafael Lima]>,
#  <User [FranclinC:Franclin Cabral]>,
#  <User [deyvisonbm:Deyvirson Mendonca]>,
#  <User [adjs:Adenilton Silva]>,
#  <User [ThomasSousa96:Thomás Sousa Silva]>,
#  <User [levisaturnino:Levi Saturnino]>,
#  <User [FelipeTrote:Felipe Trote]>,
#  <User [tonnyvx:Antonio Neto]>,
#  <User [raisagalindo:Raísa Galindo]>,
#  <User [bernardomelo:Bernardo Gomes de Melo]>,
#  <User [yeltsinlima:Yeltsin Lima]>,
#  <User [glpibr:Verdanatech Soluções em TI]>,
#  <User [especializa-user:Especializa Treinamentos]>,
#  <User [pedroboudoux:Pedro Boudoux]>,
#  <User [adailsonfilho:Adailson de Castro]>,
#  <User [feliperp-81:Felipe Rodrigues]>,
#  <User [zecafeitosa:Zeca Feitosa]>,
#  <User [diegoferreirati:Diego Ferreira]>,
#  <User [CaioMoraes:Caio Moraes]>,
#  <User [fmm:Filipe Martins]>,
#  <User [Thyerry:Thyerry Nunes]>,
#  <User [lsca:]>,
#  <User [paulobsa:Paulo R. Araújo]>,
#  <User [mangelis:Marcello Medeiros]>,
#  <User [rlom:Róger Luiz]>,
#  <User [roselmamendestw:Roselma Mendes]>,
#  <User [mmfsf:Marcos Miguel]>,
#  <User [ericklucena:Erick Lucena]>,
#  <User [gildoneto:Gildo Neto]>,
#  <User [witerbino:Wallace Viterbino]>,
#  <User [wbgalvao:Wilder B. Galvão]>,
#  <User [giovanebribeiro:Giovane Boaviagem Ribeiro]>,
#  <User [diogo-lins:Diogo Moreira Lins]>,
#  <User [lucasrbk:Lucas Amorim Vasconcelos Torres]>,
#  <User [lacerdamarcelo:Marcelo Lacerda]>,
#  <User [andredm:Andre Diniz]>,
#  <User [eduardoluiz7:Eduardo Luiz Silva]>,
#  <User [jonathasbsouza:Jônathas Souza]>,
#  <User [marlonchalegre:Marlon Chalegre]>,
#  <User [andersonpe:Anderson]>,
#  <User [vinyfalcao:Vinicius Falcão]>,
#  <User [rodrigosiqueiradev:Rodrigo Siqueira]>,
#  <User [angelobrito:Angelo Brito]>,
#  <User [viniciusmsfraga:Vinícius Fraga]>,
#  <User [caiosm1005:Caio Santana Magalhães]>,
#  <User [caiofsr:Caio Fernando]>,
#  <User [llac78:Leopoldo Costa]>,
#  <User [GeneseLessa:Gênese Lessa]>,
#  <User [jfabiofl:Fábio Fernandes]>,
#  <User [thaisabr:Thaís Burity]>,
#  <User [Matheus-Campos:Matheus Campos]>,
#  <User [brunodutra:Bruno Dutra]>,
#  <User [thyagoismael:Thyago Ismael Oliveira da Silva]>,
#  <User [felypenery:Felype Nery]>,
#  <User [thiagohenrique0810:Thiago Henrique]>,
#  <User [eduardolsneto2:Eduardo Leite]>,
#  <User [gustavolopess:Gustavo H. Lopes de Souza]>,
#  <User [jrafaelm:José Rafael Moraes]>,
#  <User [gilesv:Vinícius Giles]>,
#  <User [marconemm:Marcone Melo Mendonça]>,
#  <User [paulofloliveira:Paulo Fernando de Lima Oliveira]>,
#  <User [rafaelgsm:Rafael Montenegro]>,
#  <User [tavlima:Thiago Lima]>,
#  <User [santojon:Jonathan Santos]>,
#  <User [lucasbiagini:Lucas Biagini]>,
#  <User [saulo2:Saulo Medeiros de Araujo]>,
#  <User [phrps:Pedro Henrique Rodrigues Pereira Silva]>,
#  <User [robertoalencar:Roberto Alencar]>,
#  <User [mrrandrade:Marcelo Andrade]>,
#  <User [miguel89:Miguel Amaral]>,
#  <User [leimig:Higgor Leimig]>,
#  <User [franchenstein:Daniel K. Franch]>,
#  <User [hugoesb:Hugo Salvador]>,
#  <User [pedrodiamel:Pedro Diamel Marrero Fernández]>,
#  <User [jcrbsa:Richardson Bruno]>,
#  <User [izaiasavila:Izaias Ávila C. Filho]>,
#  <User [renatofilho:Renato Araujo Oliveira Filho]>,
#  <User [pabloreis:Pablo Reis de Queiroz]>,
#  <User [SamuelRocha2015:Samuel Rocha]>,
#  <User [brunohoppe:brunohoppe]>,
#  <User [irixs:Íris Soares]>,
#  <User [bcgs:Bruno César]>,
#  <User [Augusto94:]>,
#  <User [danilosoares:Danilo Soares]>,
#  <User [erickapsilva:Ericka Pricila]>,
#  <User [LukPOD1:José Lucas Alves da Silva]>,
#  <User [vitorbc:Vitor Costa]>,
#  <User [brunolrb:Bruno Leonardo Rodrigues Barros]>,
#  <User [joaoferreirape:João Ferreira]>,
#  <User [jonathan-silva:Jonathan Silva]>,
#  <User [johnmaykbrito:John Lima]>,
#  <User [julioamorim:Júlio Amorim]>,
#  <User [amavlopes:Amanda Avelino]>,
#  <User [fareias:Fernando Areias]>,
#  <User [Jnailson:José Nailson B. Santos]>,
#  <User [tiagotrigo:Trigo]>,
#  <User [alexodrosgomes:Alex Sandro Gomes]>,
#  <User [sabrinandrade:Sabrina Andrade]>,
#  <User [wagnerbeethoven:Wagner Beethoven]>,
#  <User [filipecmedeiros:Filipe Medeiros]>,
#  <User [nvsfs:Natália Souza]>,
#  <User [manunejaim:Manuella]>,
#  <User [wtmf:]>,
#  <User [joseviccruz:José Victor Cruz]>,
#  <User [italolemos:Ítalo Lemos]>,
#  <User [felipemobile:Felipe Andrade]>,
#  <User [feliciosan:Felício Santos]>,
#  <User [AdeildoNeto:Adeildo Neto]>,
#  <User [jhdavino:j.h.davino]>,
#  <User [felipeisidorio:Felipe Isidorio]>,
#  <User [mfeitosa:Michael Feitosa]>,
#  <User [josealbino:Jose Albino da Silva Neto]>,
#  <User [afelipefernandes:Felipe Fernandes]>,
#  <User [jbjj:Joabe Jesus]>,
#  <User [ricardo7cordas:Ricardo Freitas]>,
#  <User [ArthurLapprand:Arthur Lapprand]>,
#  <User [mateusnbm:Mateus]>,
#  <User [joaosantana:João Santana]>,
#  <User [walterjardim:Walter Jardim]>,
#  <User [jonathantsilva:]>,
#  <User [SilvaDecio:Décio Silva]>,
#  <User [wagnerbit:Wagner Bitencourt Alves]>,
#  <User [fraposo:Fernando Raposo]>,
#  <User [tiagofsilva:Tiago Farias]>,
#  <User [pnasc:Paulo Nascimento]>,
#  <User [BAMoreira:Bernardo de Azevedo Moreira]>,
#  <User [assj:Airton Soares Júnior]>,
#  <User [Wms5:Wilkinson Maciel]>,
#  <User [prximenes:Pedro Ximenes]>,
#  <User [marlom-jobsom:Marlom Oliveira]>,
#  <User [mayarajuvencio:Mayara Juvêncio da Silva Gomes]>,
#  <User [brnathanlima:Nathanael Lima]>,
#  <User [DyogoViana:Dyogo Viana]>,
#  <User [rodrigoal:Rodrigo Lobo]>,
#  <User [albinojunior:Albino Júnior]>,
#  <User [rodolfops:Rodolfo Pereira Saturnino]>,
#  <User [tuliocpbs:Tulio Cesar]>,
#  <User [EdmilsonSantana:Edmilson Santana]>,
#  <User [alicexmelo:Alice Melo]>,
#  <User [denissonsantos:Denisson Santos]>,
#  <User [manoelamorimneto:Manoel Amorim Neto]>,
#  <User [rhuandantas:Rhuan Dantas]>,
#  <User [carloseachaves:Carlos Chaves]>,
#  <User [danilocostak5:Danilo Pereira]>,
#  <User [cafmf:Carlos Alberto Fortunato]>,
#  <User [GabrielLourenco:Gabriel Lourenço]>,
#  <User [AlexandreDiegoS:Alexandre Diego]>,
#  <User [romagueralima:Arthur Lima]>,
#  <User [felipebelucena:Felipe Lucena]>,
#  <User [magalhaesrebecca:RebeccaM]>,
#  <User [tiagohas:Tiago Henrique]>,
#  <User [Kassio-Ferreira:Kássio Camelo Ferreira da Silva]>,
#  <User [diegobarcelar:Diego Barcelar]>,
#  <User [felipemarques8:Felipe Marques]>,
#  <User [marcelopita:Marcelo Pita]>,
#  <User [kepa:Lucas Lucena Falbo]>,
#  <User [dcaragao:Diego]>,
#  <User [koodaa:koda]>,
#  <User [wesleygcs:Wesley Gabriel Cardozo dos Santos]>,
#  <User [moisespalma:Moisés Simões]>,
#  <User [karollmm:Karoll Melo]>,
#  <User [pedrovsra:Pedro Tiago Araújo]>,
#  <User [filipe-torres:Filipe Torres]>,
#  <User [AleffSouza:Aleff Souza]>,
#  <User [joaopaulosama:João Paulo Santos]>,
#  <User [agcloud:Agência Cloud]>,
#  <User [giuliosa:Giulio Caetano Pires de Sá]>,
#  <User [DwarfThief:Brenno Barboza]>,
#  <User [edfcsx:Eduardo Cipriano]>,
#  <User [daniloBlera:Danilo Blera]>,
#  <User [jessica-rmo:Jéssica Oliveira]>,
#  <User [ruamberg:Ruamberg Vasconcelos Aguiar]>,
#  <User [edigomes:Edimário Gomes]>,
#  <User [udfds:Husky]>,
#  <User [jean-rar:Jean do Nascimento]>,
#  <User [UdneyCarvalho:Udney Carvalho]>,
#  <User [pdraguiar:Pedro Aguiar]>,
#  <User [tomazhawkjr:Tomaz de Aquino]>,
#  <User [madytorres:Madyana Torres]>,
#  <User [lucdias:Lucas Dias Maciel]>,
#  <User [andreximenes:Andre Luiz Ximenes G. da Luz]>,
#  <User [EduardoLisb:Eduardo Lisbôa]>,
#  <User [atailton:Atailton Tavares]>,
#  <User [andrebuarque:André Buarque]>,
#  <User [VanessaVieiraVV:Vanessa Vieira]>,
#  <User [rcbpeixoto:Rogério Peixoto]>,
#  <User [giuliocc:Giulio Carvalho]>,
#  <User [jeronimonascimento:Jerônimo do Nascimento]>,
#  <User [antonioaurel:Antonio ]>,
#  <User [Edgleyson:Edgleyson Menezes]>,
#  <User [guinetik:Joao Guilherme]>,
#  <User [netuh:Netuh]>,
#  <User [claudvanbarret:Claudivan Barreto]>,
#  <User [rafaelllins:Rafaell Lins]>,
#  <User [MaryCaroline:Mariane Pastor]>,
#  <User [rafaelwms:Rafael WMS]>,
#  <User [PedroRafaelDinizMarinho:Pedro Rafael]>,
#  <User [gdanzi:Gustavo Danzi]>,
#  <User [zearthur99:José Arthur Silveira]>,
#  <User [diegocamara:Diego Luiz]>,
#  <User [fabiorush:Fábio Urquiza]>,
#  <User [CaioMalaquias:Caio Malaquias]>,
#  <User [Galtvan:Marcos Galvão]>,
#  <User [ess2:Egberto Santana]>,
#  <User [hgees:Hericles Escoteiro]>,
#  <User [sergio3010:Sérgio Filho]>,
#  <User [ahyalla:Ahyalla Riceli]>,
#  <User [ericksantana:Erick Santana]>,
#  <User [GutenbergCarlos:Gutenberg Carlos]>,
#  <User [flavioms7:Flavio Miranda]>,
#  <User [larislav:Larissa Barros]>,
#  <User [philorocha:Felipe Vieira da Rocha]>,
#  <User [raphalencar:Raphael Brito Alencar]>,
#  <User [heldermccartney:Helder McCartney]>,
#  <User [guilherme-rdnascimento:Guilherme Nascimento]>,
#  <User [ricardorobson:Ricardo Robson]>,
#  <User [PedroHPVieira:Pedro Vieira]>,
#  <User [HuanChristopher:Huan Christopher]>,
#  <User [maysaborges:Maysa Borges]>,
#  <User [brunofalc:Bruno Falcão]>,
#  <User [klaytoncavalcante:Klayton Cavalcante]>,
#  <User [viniciosarodrigues:Vinícios A. Rodrigues]>,
#  <User [LucasFranciscoCorreia:Lucas Francisco Correia]>,
#  <User [janiosarmento:Janio Sarmento]>,
#  <User [PunishedBois:Matheus Ferreira]>,
#  <User [modcs:MoDCS Research Group]>,
#  <User [cristinesereno:Cristine Sereno]>,
#  <User [aquelefelipe:Felipe Figueiroa]>,
#  <User [atilarec:Atila Bezerra ]>,
#  <User [chgsilva:Carlos Henrique]>,
#  <User [anderssonmelo:Andersson Melo]>,
#  <User [alessandrofls:Alessandro Lima]>,
#  <User [GabrielGouv:J. Gabriel Gouveia]>,
#  <User [yalves8:Yasmin ALves]>,
#  <User [DataPE:DataPE]>,
#  <User [marcoscardoso:Marcos Cardoso]>,
#  <User [AvelinoGomez:Avelino Gomez Alonso Jr]>,
#  <User [marcosguedes01:Marcos Guedes]>,
#  <User [raissaguimaraes:Raíssa Guimarães]>,
#  <User [fhenriquecm:Flávio Macedo]>,
#  <User [pabhen:Pablo Henrique]>,
#  <User [warkentien2:Philip Warkentien II]>,
#  <User [marchesin:Anderson Marchesin]>,
#  <User [GPrimow:Gabriel Primo]>,
#  <User [AleffHenrique:Aleff Henrique]>,
#  <User [felipebagetti:Felipe Bagetti]>,
#  <User [borgiani:Felipe Borgiani]>,
#  <User [fabiolindemberg:Fabio Lindemberg]>,
#  <User [shoesthe6:Carlos Felipe]>,
#  <User [Gvascons:João Gabriel de Araújo Vasconcelos]>,
#  <User [dellanio:Dellanio Alencar]>,
#  <User [manoelfneto:Manoel Freitas]>,
#  <User [diasflp:Felipe Dias]>,
#  <User [Eviomarcio:]>,
#  <User [andredidier:André Didier]>,
#  <User [xfernando:Fernando Calheiros]>,
#  <User [ronneyluan:Ronney Bezerra]>,
#  <User [MORDC:Marcos André]>,
#  <User [hsaboya:Henrique Saboya]>,
#  <User [roMendes:Rosangela Mendes]>,
#  <User [WillyNelson:Anivaldo Junior]>,
#  <User [dayvisons:Dayvison Santos]>,
#  <User [daaysesouza:Dayse Souza]>,
#  <User [MarcoAurello:Marco Aurellio]>,
#  <User [betocabus:Alberto Cabús Junior]>,
#  <User [esdrascavalcs:Esdras Cavalcanti]>,
#  <User [betegelse:]>,
#  <User [gampeixoto:Gabriel Peixoto]>,
#  <User [dashdanilo:]>,
#  <User [KLEITONFREITAS:KF]>,
#  <User [pedrocab:Cab]>,
#  <User [mairaaraujo:Maíra Araújo]>,
#  <User [vbsilva:Vinicius Bezerra A. da Silva]>,
#  <User [allandoamaral:Allan do Amaral]>,
#  <User [wendeldesouza:wendell]>,
#  <User [thiagogalvao:Thiago]>,
#  <User [daidson:Daidson Fonseca Alves]>,
#  <User [Andre-dam:André Damázio]>,
#  <User [alanav120:Alana Vieira ]>,
#  <User [luizhsbrito:Luiz Brito]>,
#  <User [diegoMSilva:Diego]>,
#  <User [andrefilipesz:André Filipe]>,
#  <User [FilipelIOn:Filipe Lima]>,
#  <User [guuhh:Gustavo Rodrigues]>,
#  <User [henriquemc:Luiz Henrique Moura Carvalho]>,
#  <User [VictorMouraz:Victor Moura]>,
#  <User [dieggop:Dieggo Carrilho]>,
#  <User [rodrigolinsr:Rodrigo Lins]>,
#  <User [omarpta:Omar Torres]>,
#  <User [petermademann:Peter Mademann]>,
#  <User [japakr:Geovane Júnior]>,
#  <User [alinnepriscila:Alinne Priscila]>,
#  <User [tulliusvinicius:Tullius]>,
#  <User [draraujoo:Demóstenis RIbeiro de Araujo VIllar]>,
#  <User [vinimoraesrc:Vinícius de Moraes Rêgo Cousseau]>,
#  <User [galegostigma:Galego Stigma]>,
#  <User [yeltsinxyz:Yeltsin Lima]>,
#  <User [washingtonferreira:Washington Ferreira]>,
#  <User [jonatascp:Jônatas Cavalcanti Pereira]>,
#  <User [jonolo6:Jonas Olofsson]>,
#  <User [alnp:Alessandra Pereira]>,
#  <User [diogocaetano:Diogo Caetano Alves Firmo]>,
#  <User [daniellyqueiroz:Danielly Queiroz]>,
#  <User [fjuriolli:Fernando Juriolli]>,
#  <User [DaviBFarias:DB Farias]>,
#  <User [ajgan:Antonio Gadelha]>,
#  <User [itsCleyton:Cleyton C.]>,
#  <User [jvog:José Vogeley Alves de Sá]>,
#  <User [SirLVF:Lindeberg Vital de Freitas]>,
#  <User [brfael:RAFAEL DE LUCENA FALCÃO]>,
#  <User [pedrojsn96:]>,
#  <User [lucianasilva:Luciana Maria de Araújo Silva]>,
#  <User [leoomelo:Leonardo Melo]>,
#  <User [lmyboy:Lucas Cavalcanti]>,
#  <User [slunart:Samuel Martins]>,
#  <User [EwertonQueiroz:Ewerton]>,
#  <User [WesleyJw:Wesley Lima]>,
#  <User [euclidesgc:Euclides G. Catunda]>,
#  <User [matheusmmx:Matheus]>,
#  <User [caiochagas:Caio Chagas]>,
#  <User [dpm-cin:Diogo Morais]>,
#  <User [acaxon:Antonio Carlos Amaral]>,
#  <User [hfcamilo:Hugo Felipe Camilo]>,
#  <User [rnns:Rafael Nunes Machado]>,
#  <User [aeciojr:Aécio Júnior]>,
#  <User [buarquepedro:Pedro Buarque]>,
#  <User [monteiro-luiz:Luiz Monteiro]>,
#  <User [gugacarvalho:Guga Carvalho]>,
#  <User [rcananea:Ronaldo Cananéa]>,
#  <User [andersongimino:Anderson Gimino]>,
#  <User [joaoluizdhv:João Luiz D. H. Valença]>,
#  <User [albjoaov:João Victor]>,
#  <User [marcomachado:Marco André Machado]>,
#  <User [xewertonfilipe:Ewerton Filipe]>,
#  <User [EduardoAmaral:Eduardo Fabricio Santana do Amaral]>,
#  <User [elloserafim:Ello Oliveira]>,
#  <User [WilbertoFilho:Wilberto Filho]>,
#  <User [Edy8123:Edyniesky Ferrer]>,
#  <User [84PC04:Prisciliano Costa]>,
#  <User [belcsantiago:Isabel Santiago]>,
#  <User [feliperfmarques:Felipe Marques]>,
#  <User [felipedemacedo:Felipe de Macêdo]>,
#  <User [Gabisampaio:Gabriela Sampaio]>,
#  <User [paguso:Paulo Fonseca]>,
#  <User [lfcdsg88:Luiz Fernando Gomes]>,
#  <User [orlandoaceto:Orlando Verdasca Aceto]>,
#  <User [diegotsouza83:Diego Souza]>,
#  <User [LABCEUS:Laboratório de Cidades Sensitivas]>,
#  <User [denisreis:Denis Reis]>,
#  <User [zLimaa:Ricardo Lima]>,
#  <User [itamarsilva:Itamar Silva]>,
#  <User [flaviohmaia:Flavio Maia]>,
#  <User [altemberg:Altemberg Andrade]>,
#  <User [absilva:Alex Batista]>,
#  <User [gan640:Gabriel Bortoloto]>,
#  <User [rodrigoaccountaccenture:Rodrigo B. Cavalcanti]>,
#  <User [apfmiranda:Alexandre]>,
#  <User [lflucasferreira:Lucas Ferreira]>,
#  <User [andalvalmeida:André Almeida]>,
#  <User [RobsonMarinho:Robson Marinho]>,
#  <User [josenetome:José Neto]>,
#  <User [sofiagalvao:Sofia Galvão]>,
#  <User [igoleo:Igor Gomes]>,
#  <User [ioram7:Ioram Sette]>,
#  <User [JPMagalhaes:JP Magalhaes]>,
#  <User [vitorcruz8621:Vitor Cruz]>,
#  <User [AdoniasBarros:Adonias Barros]>,
#  <User [UmbertoB:]>,
#  <User [klaytondeoliveira:Klayton de Oliveira]>,
#  <User [renatalourena:]>,
#  <User [matheusqfs:Matheus Feitosa]>,
#  <User [krixapolinario:Krix Apolinário]>,
#  <User [ricardovasc:Ricardo Vasconcelos]>,
#  <User [thiagolins:Thiago Lins]>,
#  <User [NthlLima:Nathalia Lima]>,
#  <User [EduardoFreit:Luiz Eduardo Pessoa de Freitas]>,
#  <User [charles-alves:Charles Siqueira Alves]>,
#  <User [RodrigoRodrigues7:Rodrigo Rodrigues]>,
#  <User [wlcosta:Willams de Lima]>,
#  <User [andreporto:André Porto]>,
#  <User [eratsu:Guilherme Lins]>,
#  <User [robsonribeiros:Robson Ribeiro]>,
#  <User [mateus-nascimento:mateus nascimento]>,
#  <User [brunobpb:Bruno Braga]>,
#  <User [uillaneduardo:Uillan Eduardo]>,
#  <User [MartinsMateus:Mateus Martins]>,
#  <User [FlavioCastroFilho:Flavio Castro]>,
#  <User [lrsilva:Leandro Silva]>,
#  <User [keywilliams:Key Williams]>,
#  <User [WallaceRocha:Wallace Rocha]>,
#  <User [julianophp:Juliano Mesquita dos Santos]>,
#  <User [cleytonfar:cleyton_farias]>,
#  <User [augustolimasilva:Augusto Lima da Silva]>,
#  <User [peedrogabriel:Pedro_Lima]>,
#  <User [VictorManoel:Victor Manoel]>,
#  <User [Tiagoemerenciano:Tiago Emerenciano]>,
#  <User [hrmd:Hugo Daher]>,
#  <User [arthur-rizzo:Arthur Rizzo]>,
#  <User [diogoan:Diogo Nóbrega]>,
#  <User [rpss2:Ramom Pereira]>,
#  <User [wsena:Wanessa Sena]>,
#  <User [JamessonCheron:Jamesson Cheron]>,
#  <User [Italord0:Italo Melo]>,
#  <User [tantodom:TantoDom Comunicação]>,
#  <User [rcursino:Rodrigo Cursino]>,
#  <User [sheylacanutobf:Sheyla Canuto]>,
#  <User [walfredosa:Walfredo de Sá]>,
#  <User [igorhlucenaa:Igor Lucena]>,
#  <User [ricardoebbers:Ricardo Ebbers]>,
#  <User [tiagonog:Tiago Nogueira]>,
#  <User [JeffersonLPLima:Jefferson Luiz Pessoa Lima]>,
#  <User [joaopaulogf:joão]>,
#  <User [tuliocrr:Túlio Carvalho]>,
#  <User [hmilena:Mia]>,
#  <User [caioamorim031:Caio Amorim]>,
#  <User [reforcomestrado2015:Grupo 2 - Disciplina de Engenharia de Software Mestrado Profissional]>,
#  <User [ebl4:Edson]>,
#  <User [adozrocha:Ado Rocha]>,
#  <User [Fabio-Lins:Fábio lins]>,
#  <User [empacto:Empacto ]>,
#  <User [cassiorsfreitas:Cássio Freitas]>,
#  <User [iurylira:Iury Lira Ribeiro]>,
#  <User [HerlonNascimento:Herlon Nascimento]>,
#  <User [TCezarRod:Thalles Cezar]>,
#  <User [GabrielaMattias:Gabriela Matias]>,
#  <User [hugosteixeira:Hugo Teixeira]>,
#  <User [mattvie:Mateus Viégas]>,
#  <User [brunoeee:Bruno Magalhães]>,
#  <User [rodrigomuribec:Rodrigo Lins Rodrigues]>,
#  <User [evandroabreu:Evandro Sousa de Abreu]>,
#  <User [sunr00t:Bruno Nascimento]>,
#  <User [angelamcosta:Angela Lima]>,
#  <User [dolalima:Dola]>,
#  <User [andreguigo:André Albuquerque]>,
#  <User [felipemdmelo:Felipe Melo]>,
#  <User [AdrianoDayvson:Adriano Dayvson]>,
#  <User [DoodleWeb:DoodleWeb]>,
#  <User [cirg-upe:Computational Intelligence Research Group - University of Pernambuco]>,
#  <User [hugonmelo:Hugo Melo]>,
#  <User [victor-cortez:Victor Cortez]>,
#  <User [valongueiro:André Valongueiro]>,
#  <User [dofobatista:Rodolfo Batista do Espírito Santo]>,
#  <User [rfccg:Rafael Gouveia]>,
#  <User [gertmuller88:Gert Müller]>,
#  <User [FernandoRLCruz:fernando cruz]>,
#  <User [iatj:IvanT]>,
#  <User [haroldogondim:Haroldo Gondim]>,
#  <User [andreleitao:Andre Leitao]>,
#  <User [islanilton:Islanilton Rodrigues]>,
#  <User [rodrigoadamski:Rodrigo Adamski]>,
#  <User [lucaspcburgos:Lucas Burgos]>,
#  <User [sccrn:Samanta Coutinho]>,
#  <User [LDGNeto:Leonilde Diogenes Gurgel Neto]>,
#  <User [kevenleone:Keven Leone]>,
#  <User [lericardolima:Ricardo Lima]>,
#  <User [sandrocavalcanti:Sandro Cavalcanti]>,
#  <User [erikcordeiro:Éric Cordeiro]>,
#  <User [dmfilho:Dimas Melo Filho]>,
#  <User [cleniomendes:Clenio Mendes]>,
#  <User [feliperod:Felipe Rodrigues]>,
#  <User [AlefRGamer:Alef Ronaldo Palmeira dos Santos]>,
#  <User [igorsimoes:Igor Simões]>,
#  <User [fdsadat:Felipe Duarte de Santana]>,
#  <User [PauloAlves3486:Paulo Alves]>,
#  <User [brenodvs:Breno de Vasconcelos Santos]>,
#  <User [wizdow:Jair Medeiros Ferreira Filho]>,
#  <User [carlosliracl:Carlos Lira]>,
#  <User [DodoAz:Douglas Azevedo Pereira Dantas]>,
#  <User [sjcleao:Sergio Leao]>,
#  <User [douglasbrandao00:Douglas Willian de Farias Brandão]>,
#  <User [BrunoBA:Bruno Barros]>,
#  <User [zchronoz:Gabriel Vasconcelos]>,
#  <User [leolsrd:Léo Lourenço Santa Rosa Dutra]>,
#  <User [FernandaLandim:Fernanda Granja Landim]>,
#  <User [anakcampelo:Ana Katarina Campelo]>,
#  <User [marcelotheodoro:Marcelo Theodoro]>,
#  <User [grfneto:]>,
#  <User [gabrielbazante:Gabriel Bazante]>,
#  <User [petrusaugusto:Petrus Augusto]>,
#  <User [madsonmuller:Madson Muller]>,
#  <User [staylward:]>,
#  <User [aht360:Augusto Henriques Terra]>,
#  <User [guilhermegomes01:Guilherme Gomes]>,
#  <User [RichardSilva12:Richard Silva]>,
#  <User [hcaula:Henrique Caúla]>,
#  <User [brazsandro:Sandro Braz]>,
#  <User [rfccn:Ricardo Ferreira da Costa Campos Neto]>,
#  <User [claudiopacheco:Claudio Pacheco]>,
#  <User [jimens:Jimens Lima]>,
#  <User [deyvisonrochaidealizza:Deyvison Rocha]>,
#  <User [jalexc:Alex Carneiro]>,
#  <User [vmoliveira91:Vitor Oliveira]>,
#  <User [gtgsantos:Guilherme Santos]>,
#  <User [netoffdf:Francisco Dias]>,
#  <User [filipeaguiar:Filipe Aguiar]>,
#  <User [pedrohub:Pedro Edson]>,
#  <User [vandialves:Vandi Alves]>,
#  <User [cesarsantana2:César Santana]>,
#  <User [carlosmax:Carlos Max]>,
#  <User [lauriavictor7:]>,
#  <User [SoulFlybr:João Gabriel]>,
#  <User [fernandohenriqueguimaraes:Fernando Henrique Guimarães]>,
#  <User [eduardascharnhorst:]>,
#  <User [flavindias:Flaviano Dias]>,
#  <User [MateusLoureiro:Mateus Loureiro]>,
#  <User [tamiresa:Tamires Agripino ]>,
#  <User [mcdsb:Mônica Crystine da Silva Bezerra]>,
#  <User [batebit:Batebit Artesania Digital]>,
#  <User [juniorbrasil:Junior Brasil]>,
#  <User [deisesouza:Deise Souza]>,
#  <User [RenatoRJF:Renato Ferreira]>,
#  <User [joaovictortinoco:João Victor Tinoco]>,
#  <User [GabrielSDG:Gabriel D'Emery]>,
#  <User [gabrielteotonio:Gabriel Teotonio]>,
#  <User [marcuscarneiro:Marcus Carneiro]>,
#  <User [EBDAF1:Eraldo Barbosa dos Anjos Filho]>,
#  <User [diegomarinho:Diego Marinho]>,
#  ...]

# %%
ghuser = full_ghusers_batches[0][12]

print([ghuser.iter_followers()])

# %% [markdown]
# # Users

# %%
def create_users_df(batches):
    return pd.concat(
        [pd.DataFrame({'User': u}) for u in batches],
        ignore_index=True)

# %%
gh_users = create_users_df(full_ghusers_batches)

# %%
gh_users.head()

# %%
gh_users.describe()

# %% [markdown]
# # Followers

# %%
def followers_map(gh_user):
    '''  Map  '''
#     print(gh_user)
    return ','.join([str(u) for u in gh_user.iter_followers()])
#     return pd.DataFrame({'User': 
#                          [str(u) for u in gh_user.iter_followers()]
#                         })


def map_f_batch(map_fn, users_iterator):
    '''
    
    '''
#     print()
    return pd.DataFrame({'Followers': [map_fn(u) for u in users_iterator]})


def create_followers_df(batches):
    return pd.concat(
        [map_f_batch(followers_map, u) for u in batches],
        ignore_index=True)

# %%
gh_followers = create_followers_df(full_ghusers_batches)

# %%
gh_followers.head()
# Out:
#                                            Followers
# 0  Sannis,danielmahon,csjaba,FergusRedican,Victor...
# 1  brunocoelho,henvic,eduardolundgren,aperrelli,a...
# 2  renatooliveira,jeffesonmaia,jotaefe,duartefq,J...
# 3  thiagoarrais,brunojm,henriquebastos,macndesign...
# 4  brunohenrique,luizvarela,gladson,lucasbibiano,...

# %%
gh_followers.describe()
# Out:
#                                         Followers
# count                                        2015
# unique                                       2015
# top     Empty DataFrame
# Columns: [User]
# Index: []
# freq                                            1

# %%
gh_followers['nF'] = gh_followers['Followers'].apply(len)
gh_followers.head()
# Out:
#                                            Followers   nF
# 0                       User
# 0                  S...  567
# 1                     User
# 0           brunocoelh...  371
# 2                    User
# 0       renatooliveira
# ...  352
# 3                   User
# 0        thiagoarrais
# 1 ...  335
# 4                  User
# 0      brunohenrique
# 1   ...  305

# %%
# pd.DataFrame({'User':gh_users['User']}).merge()
gh_users_followers = gh_users.join(gh_followers)
gh_users_followers.head()
# Out:
#               User                                          Followers   nF
# 0          tarruda                       User
# 0                  S...  567
# 1         mairatma                     User
# 0           brunocoelh...  371
# 2  joselitojunior1                    User
# 0       renatooliveira
# ...  352
# 3  marcelcaraciolo                   User
# 0        thiagoarrais
# 1 ...  335
# 4      luanfonceca                  User
# 0      brunohenrique
# 1   ...  305

# %%
gh_users_followers.describe()
# Out:
#                 nF
# count  2015.000000
# mean      6.079901
# std      25.578395
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       4.000000
# max     567.000000

# %%
# gh_users_followers.to_csv('../data/tmp_users__followers.csv', index=False)

# %% [markdown]
# # Repos

# %%
# aguardar API rate (em torno de 1h)

def repositories_map(gh_user, repo_type):
    return [u for u in gh.iter_user_repos(gh_user, type=repo_type)]

def map_r_batch(map_fn, users_iterator):
    return pd.DataFrame({'Repo_Owner':[map_fn(u, 'owner') for u in users_iterator],
                         'Repo_Member': [map_fn(u, 'member') for u in users_iterator]})

def create_repositories_df(batches):
    return pd.concat(
        [map_r_batch(repositories_map, u) for u in batches], 
        ignore_index=True)


gh_repositories = create_repositories_df(full_ghusers_batches)
gh_repositories
# Out:
#                                              Repo_Owner  \
# 0     [tarruda/Algoritmos, tarruda/archdb, tarruda/b...
# 1     [mairatma/alloy-ui, mairatma/alloyui.com, mair...
# 2     [joselitojunior1/abigobaldo-nunes-adventures, ...
# 3     [marcelcaraciolo/apontador-api-libs, marcelcar...
# 4     [luanfonceca/168horas, luanfonceca/4stoq, luan...
# 5     [deividazevedo2/AprendendoPHP, deividazevedo2/...
# 6     [simoneas02/2017-goals, simoneas02/2018-goals,...
# 7     [gileno/analise-dados-imobiliarios, gileno/API...
# 8     [filipeximenes/agendacultural, filipeximenes/b...
# 9     [renatooliveira/authomatic, renatooliveira/cel...
# 10    [luiztiago/android-watchlist, luiztiago/bada-p...
# 11    [ac-pm/CertPinning, ac-pm/for-tests, ac-pm/Ins...
# 12    [fernandocastor/5linguagens, fernandocastor/au...
# 13    [henvic/2016-talks, henvic/accidents, henvic/a...
# 14    [clovisdasilvaneto/adesivos, clovisdasilvaneto...
# 15    [fjsj/1001, fjsj/arrow, fjsj/awesome-static-an...
# 16    [zimmerle/abel, zimmerle/airprobe, zimmerle/ai...
# 17    [adrielcafe/adriel.cafe, adrielcafe/adrielcafe...
# 18    [talitaoliveira/33DiasSemMachismo, talitaolive...
# 19    [arthuralvim/airflow-stack, arthuralvim/ansibl...
# 20    [paulorec/8bits-parallel-port-manipulation, pa...
# 21    [dmesquita/arxiv-sanity-preserver, dmesquita/B...
# 22    [ktquez/awesome-vue, ktquez/Inspect, ktquez/kt...
# 23    [guilhermefarias/AndroidCheckList, guilhermefa...
# 24    [brunofarache/alloy-ui, brunofarache/docker-li...
# 25    [lailsonbm/2d_semi_supervised, lailsonbm/ABNT2...
# 26    [lmmenge/lmmenge.github.com, lmmenge/MeSNEmu, ...
# 27    [brunobasto/accessibility-activity, brunobasto...
# 28    [guiocavalcanti/comics-reader, guiocavalcanti/...
# 29    [pcstl/.emacs.d, pcstl/1ppmLog, pcstl/8chip, p...
# ...                                                 ...
# 1985                                                 []
# 1986                                                 []
# 1987                                                 []
# 1988                                                 []
# 1989                           [kauparesque/studyGroup]
# 1990                                                 []
# 1991                             [livox/livox_homepage]
# 1992                               [abic-ong/abiclinux]
# 1993                                                 []
# 1994                                      [icsouza/ics]
# 1995                                                 []
# 1996                                                 []
# 1997  [gmenge/framework-atacama, gmenge/if672, gmeng...
# 1998                     [cfregis/LBE-Challenge-201805]
# 1999  [dvnp/802.15.4, dvnp/knot-gateway-buildroot, d...
# 2000  [Openredu/analytics, Openredu/apps, Openredu/a...
# 2001  [jacscin/hello-world, jacscin/hello-world.gith...
# 2002  [marcosjppf/AnsFileManager, marcosjppf/ToggleApp]
# 2003                                                 []
# 2004  [prfrancaf/appium-sample, prfrancaf/aula_pug, ...
# 2005          [prgc/am, prgc/primeiroteste, prgc/teste]
# 2006                                                 []
# 2007  [gleydsonageu/couser-new, gleydsonageu/Estudan...
# 2008  [P2Mdotcom/code-git, P2Mdotcom/Project_ITnsify...
# 2009                                                 []
# 2010                         [Humbertobz26/Cobrinha.io]
# 2011                           [hqlpedro/roughness-map]
# 2012  [hugorlima/app-saude, hugorlima/app-saude-1, h...
# 2013  [leettech/laravel-flagger, leettech/phpunit-wa...
# 2014  [disias/dauster, disias/Design-Pattern, disias...
#
#                                             Repo_Member
# 0                                   [libmpack/libmpack]
# 1     [deprecate/steel-avatar, deprecate/steel-cell-...
# 2     [acmh/maecoruja, Cisneiros/projeto-anfa, demia...
# 3     [irgmedeiros/TCCRecommender, jg1141/Open-Allur...
# 4     [andrezap/analise_expressao_genica, andrezap/a...
# 5     [DarthHugh/Scream, IndyPaula/HumQueCaro, IndyP...
# 6     [afonsopacifer/css-grid-layout-manual, CodeMig...
# 7     [demacdolincoln/Analise_de_Dados_de_Redes_Soci...
# 8     [tapanpandita/pocket, vintasoftware/django-app...
# 9     [alessandroHenrique/coinpricemonitor, filipecm...
# 10      [dfmedeiros/trellando, djalmaaraujo/socketrace]
# 11                                                   []
# 12    [curso-scm/scm, rafaelbrandao/deadlock-excepti...
# 13    [brunabaudel/taste, guedesbgeorge/IF1006-Proje...
# 14    [all-animation/all-animation, cirocosta/sample...
# 15                             [dudurocha/hackernewsbr]
# 16    [SpiderLabs/ModSecurity-log-utilities, SpiderL...
# 17    [AJS99/caderno-online, AJS99/caderno-online-an...
# 18    [jonathanslima/flexbox-training, tuliocrr/indi...
# 19    [dojodocirculo/dojodocirculo.github.io, Tiago-...
# 20                                      [thiagoh/poker]
# 21    [dhsm/middleware-distribuida, dhsm/PRODUCAOACA...
# 22                      [trickstival/code-for-facebook]
# 23    [agencia-watermelons/meugarcon, henvic/invento...
# 24    [barkefors/camel-liferay, johnnyhowey/Hackday-...
# 25    [gvc/libertas, jeffp/enumerated_attribute, ser...
# 26                                                   []
# 27    [leoadb/com-liferay-dynamic-data-mapping, life...
# 28    [acvilarim/politicAPI, Bouckaert/rubber-test, ...
# 29    [iacapuca/analisecandidatos, iacapuca/hackatho...
# ...                                                 ...
# 1985                                                 []
# 1986                                                 []
# 1987                                                 []
# 1988                                                 []
# 1989                                                 []
# 1990                                                 []
# 1991                             [livox/livox_homepage]
# 1992                               [abic-ong/abiclinux]
# 1993                                                 []
# 1994                                                 []
# 1995                                                 []
# 1996                                                 []
# 1997  [IF977/MedicalHelp-Recife, MateusPonciano/Proj...
# 1998                                                 []
# 1999                                                 []
# 2000  [Openredu/analytics, Openredu/apps, Openredu/a...
# 2001                              [marcogmaia/proj_com]
# 2002                                                 []
# 2003                                                 []
# 2004                                                 []
# 2005                                      [mrcferro/am]
# 2006                                                 []
# 2007  [arianalima/WhereverIgo, leuthier/RuralMaps, l...
# 2008                                                 []
# 2009                            [paslucena/comunicacao]
# 2010                                                 []
# 2011                                   [gaabs/amazonia]
# 2012                                [HIttWeb/app-saude]
# 2013                                                 []
# 2014                                                 []
#
# [2015 rows x 2 columns]

# %%
gh_repositories.head()
# Out:
#                                           Repo_Owner  \
# 0  [tarruda/Algoritmos, tarruda/archdb, tarruda/b...
# 1  [mairatma/alloy-ui, mairatma/alloyui.com, mair...
# 2  [joselitojunior1/abigobaldo-nunes-adventures, ...
# 3  [marcelcaraciolo/apontador-api-libs, marcelcar...
# 4  [luanfonceca/168horas, luanfonceca/4stoq, luan...
#
#                                          Repo_Member
# 0                                [libmpack/libmpack]
# 1  [deprecate/steel-avatar, deprecate/steel-cell-...
# 2  [acmh/maecoruja, Cisneiros/projeto-anfa, demia...
# 3  [irgmedeiros/TCCRecommender, jg1141/Open-Allur...
# 4  [andrezap/analise_expressao_genica, andrezap/a...

# %%
# linguagem do repositorio
gh_repositories['mRepo_Language'] = gh_repositories['Repo_Member'].apply(lambda x: ','.join([str(y.language) for y in x]))
gh_repositories['oRepo_Language'] = gh_repositories['Repo_Owner'].apply(lambda x: ','.join([str(y.language) for y in x]))

# normalizando
gh_repositories['Repo_Member'] = gh_repositories['Repo_Member'].apply(lambda x: ','.join([str(y) for y in x]))
gh_repositories['Repo_Owner']  =  gh_repositories['Repo_Owner'].apply(lambda x: ','.join([str(y) for y in x]))

gh_repositories = gh_repositories.reindex(['Repo_Member', 'mRepo_Language', 'Repo_Owner','oRepo_Language'], axis=1)

# gh_repositories.head()
gh_users_repositories = gh_users.join(gh_repositories)

gh_users_repositories.head()
# Out:
#               User                                        Repo_Member  \
# 0          tarruda                                  libmpack/libmpack
# 1         mairatma  deprecate/steel-avatar,deprecate/steel-cell-de...
# 2  joselitojunior1  acmh/maecoruja,Cisneiros/projeto-anfa,demianbo...
# 3  marcelcaraciolo   irgmedeiros/TCCRecommender,jg1141/Open-Allure-DS
# 4      luanfonceca  andrezap/analise_expressao_genica,andrezap/arv...
#
#                                       mRepo_Language  \
# 0                                                  C
# 1  CSS,CSS,HTML,CSS,HTML,CSS,JavaScript,CSS,JavaS...
# 2          JavaScript,Java,Java,HTML,JavaScript,None
# 3                                      Python,Python
# 4  Java,Java,Java,Ruby,Ruby,JavaScript,JavaScript...
#
#                                           Repo_Owner  \
# 0  tarruda/Algoritmos,tarruda/archdb,tarruda/back...
# 1  mairatma/alloy-ui,mairatma/alloyui.com,mairatm...
# 2  joselitojunior1/abigobaldo-nunes-adventures,jo...
# 3  marcelcaraciolo/apontador-api-libs,marcelcarac...
# 4  luanfonceca/168horas,luanfonceca/4stoq,luanfon...
#
#                                       oRepo_Language
# 0  JavaScript,JavaScript,JavaScript,JavaScript,Py...
# 1  JavaScript,JavaScript,TypeScript,JavaScript,Ja...
# 2  JavaScript,HTML,CSS,None,None,None,None,GCC Ma...
# 3  PHP,Python,Python,None,Python,Python,Python,No...
# 4  CSS,Ruby,Python,JavaScript,Python,Python,None,...

# %%
# export
# gh_users_repositories.to_csv('../data/tmp_users__repositories.csv', index=False)

# %% [markdown]
# ## Backup dos dados coletados no momento do scraping
# **Note que o usuário pode não existir mais ou ter mudado o seu username, etc.**

# %%
# # Users trabalhados no projeto
# backup_batch_df = pd.read_csv('../data/users__followers.csv')
# b_ghusers_batch = backup_batch_df['User'].tolist()

# # trata users nao encontrados
# full_ghusers_batches2 = [[gh.user(x) for x in b_ghusers_batch if gh.user(x) is not None]]

# gh_users2 = create_users_df(full_ghusers_batches2)

# # atualiza os seguidores dos users
# gh_followers2 = create_followers_df(full_ghusers_batches2)

# %%
# aguardar API rate 
# atualiza os repositorios dos users
# gh_repositories2 = create_repositories_df(full_ghusers_batches2)
